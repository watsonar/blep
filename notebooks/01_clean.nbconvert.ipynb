# %%
from datetime import date
import pandas as pd
import sys
sys.path.append('../src')
import data.clean as clean
import numpy as np

# %% [markdown]
# # Read external data into a pandas df

# %%
today = date.today()
d = today.strftime('%Y_%m_%d')
#d = '2020_11_25'

df = pd.read_csv(f'../data/external/raw_chewy_data_{d}.csv')

# %% [markdown]
# # Clean data
#
# ## Unpack attribute and guarenteed analysis (GA) dictionaries
# import reAttribute information and guarenteed analysis (GA) information are stored as dictionaries in their columns. This is because different products have different fields/numbers of fields in these tables. So first things first, expand those two columns.

# %%
# help(clean.dict_col_to_cols)

df = clean.dict_col_to_cols(df=df, col='ga_dict', ga=True)
df = clean.dict_col_to_cols(df=df, col='attr_dict', ga=False)

# %% [markdown]
# ## Fill guarenteed analysis columns missing critical statistics
#
# It is mandatory that cat food manufacturers report % protein min, % fat min, and % fiber max in their guarenteed analysis. So it's likely that when there isn't a value for one of these macros, but there is a value for a very similarly named macro, a typo has been made. So we need to fill empty macro values with the values most likely to be correct.

# %%
df['% protein min'] = df['% protein min'].fillna(df['% protein']).fillna(df['% protein max'])
df['% fat min'] = df['% fat min'].fillna(df['% fat']).fillna(df['% fat max'])
df['% fiber max'] = df['% fiber max'].fillna(df['% fiber']).fillna(df['% fiber min'])
df['% moisture max'] = df['% moisture max'].fillna(df['% moisture']).fillna(df['% moisture min'])

# df = df.dropna(thresh = df.shape[0] * 0.5, how = 'all', axis = 1)

# %% [markdown]
# ## Add up percentages of misc. guarenteed analysis componenets
# There are so many miscellaneous compounds that are included in only a handful of the products' guarenteed analysis. We want the percent values for these compounds, because they will help us calculate % carbohydrates later, but we don't need them individually. So we want to add up the columns that start with '%' and are not protein, fat, fiber, moisture, or carbohydrate (a few products have this value, but we will be calculating it for all products). If the sum of these columns is 100% or greater, we know something has gone terribly wrong (I found a typo...) so we will set that value to nan.

# %%
macros = ('protein', 'fat', 'fiber', 'moisture', 'carbohydrate')

misc_components = [col for col in df if '%' in col and not any(macro in col for macro in macros)]

df['% misc components'] = df[misc_components].sum(axis=1)

df.loc[df['% misc components'] >= 100, '% misc components'] = np.nan

# %% [markdown]
# ## Extract kilocalories/mass or kilocalories/volume
# The calories column contains information about the number of kilocalories per unit mass or volume of food. However, the units are not consistent, and often multiple values are reported. So we can pull out the kcal/unit mass for dry food, and the kcal/unit volume for wet food (this is because total product size is given in mass for dry food and volume for wet food, and we'd like to eventually calculate U.S. dollar per kcal).

# %%
# help(clean.get_unit_val_col)

# kcal/unit of mass:
df = clean.get_unit_val_col(df, column_name = 'calories',
                  col_split_regex = '(?<!/) (?=\d)|,|;|:',
                  unit_name = 'kcal_per_kg',
                  unit_regex = 'kcal.*kg')

df = clean.get_unit_val_col(df, column_name = 'calories',
                  col_split_regex = '(?<!/) (?=\d)|,|;|:',
                  unit_name = 'kcal_per_lb',
                  unit_regex = 'kcal.*lb')

# kcal/unit of volume:
df = clean.get_unit_val_col(df, column_name = 'calories',
                  col_split_regex = '(?<!/) (?=\d)|,|;|:',
                  unit_name = 'kcal_per_oz',
                  unit_regex = 'kcal.*oz|kcal.*ounce')

df = clean.get_unit_val_col(df, column_name = 'calories',
                  col_split_regex = '(?<!/) (?=\d)|,|;|:',
                  unit_name = 'kcal_per_cup',
                  unit_regex = 'kcal.*cup')

# kcal/item (kcal in a single can, pouch, etc.)
df = clean.get_unit_val_col(df, column_name = 'calories',
                  col_split_regex = '(?<!/) (?=\d)|,|;|:',
                  unit_name = 'kcal_per_item',
                  unit_regex = 'kcal.*can|kcal.*pouch|kcl.*pouch|kcal.*unit|kcal.*bowl|kcal.*tray|kcal.*container|kcal.*serving|kcal.*tub|kcal.*pack',
                  clear_inconsistent_rows = False,
                  get_denom_col = True,
                  denom_name = 'item_volume_for_kcal',
                  denom_regex = '((?<=\/).*?\d+\.?\d+)')

# %% [markdown]
# ## Extract item mass, volume, and/or count
# For dry food we need the total mass of the bag, for wet food we need the total volume of the can/item unit and the number of cans/item units.

# %%
# number of lbs per item
df = clean.get_unit_val_col(df, column_name = 'name',
                  col_split_regex = ',',
                  unit_name = 'total_mass_lb',
                  unit_regex = 'lb|pound|Pound')

# if no number lbs found, get that value from the weight attribute 
# DO NOT DO THIS WEIGHTS ARE NOT ALL IN LBS
# df['total_mass_lb'] = df['total_mass_lb'].fillna(df['weight'])

# number of ounces per item
df = clean.get_unit_val_col(df, column_name = 'name',
                  col_split_regex = ',',
                  unit_name = 'item_oz',
                  unit_regex = 'oz|ounce')

# number of items
df = clean.get_unit_val_col(df, column_name = 'name',
                  col_split_regex = ',',
                  unit_name = 'item_count',
                  unit_regex = 'case of')

# if no number of items specified, set item_count to 1
df['item_count'] = df['item_count'].fillna(1)

# %% [markdown]
# # Filling values and adding warnings
# ## Nutritional info
# For nutritional information, we need to know AT LEAST the % protein min, % fat min, and % moisture. % fiber max should also be provided. To calculate the cost per kilocalorie, we need the prouct price, and the kilocalories per product.

# %%
missing_ga = df[df['% protein min'].isna() | df['% fat min'].isna() | df['% fiber max'].isna()]

print(f'There are %d products out of %d which are missing protein, fat, or fiber info.' 
      % (len(missing_ga), len(df)))

missing_moisture = df[df['% protein min'].notnull() & df['% fat min'].notnull() & df['% fiber max'].notnull() & df['% moisture max'].isna()]

print(f'There are %d products out of %d which have all protein, fat, and fiber info, but not moisture.' 
      % (len(missing_moisture), len(df)))
# Out:
# There are 16 products out of 2071 which are missing protein, fat, or fiber info.
# There are 49 products out of 2071 which have all protein, fat, and fiber info, but not moisture.

# %% [markdown]
# The average wet cat food and the average dry cat food are supposed to have 75-78% and 10-12% moisture max, respectively (https://www.petfoodinstitute.org/the-whole-bowl/z-pet-food-4-things-know-dry-pet-food/).
# We could assign those moisture values to the foods that are missing moisture information but have all the other nutrient values.
#
# Out of curiosity, do those values reflect the average moisture for wet and dry cat food in this data?

# %%
wet_mean = df[df['food form'].str.contains('wet food', na=False)]['% moisture max'].mean()

dry_mean = df[df['food form'].str.contains('dry food', na=False)]['% moisture max'].mean()

print(f'In this data, wet food has a mean percent moisture max of %d percent, \
and dry food has a mean percent moisture max of %d percent.' 
      % (wet_mean, dry_mean))
# Out:
# In this data, wet food has a mean percent moisture max of 80 percent, and dry food has a mean percent moisture max of 9 percent.

# %% [markdown]
# ### Assuming moisture content
# For all products that have values for protein, fat, and fiber, but are missing a value for moisture, we can fill in the moisture value with an estimate based on if the food is wet or dry. But if we do this, we should add a warning column stating that this value was estimated.

# %%
df['moisture_warning'] = np.nan

df.loc[df['food form'].str.contains('wet food') 
       & df['% protein min'].notnull() 
       & df['% fat min'].notnull() 
       & df['% fiber max'].notnull() 
       & df['% moisture max'].isna(), 
       ['% moisture max', 'moisture_warning']] = [76.5, '% moisture max estimated']

df.loc[df['food form'].str.contains('dry food') 
       & df['% protein min'].notnull() 
       & df['% fat min'].notnull() 
       & df['% fiber max'].notnull() 
       & df['% moisture max'].isna(), 
       ['% moisture max', 'moisture_warning']] = [11, '% moisture max estimated']

# %% [markdown]
# ## Kilocalories/product
# Calculating kilocalories per product is a bit trickier. We need to make sure we're not mistaking mass with volume. When wet food is measured in ounces, they are fluid ounces. But if we're given the calorie content of a wet food only in kcal/kg, we can't convert fluid ounces to kilograms, because we don't know the density of the wet food (though most wet food is ~78% water).
#
# So for each product we need price, and either:
#
# 1. kcal/unit of volume (cups or ounces)
# 2. item volume (cups or ounces)
#
# OR
#
# 1. kcal/unit of mass (kg or lb)
# 2. item mass (kg or lb)
#
# OR
#
# 1. kcal/item
# 2. item count

# %%
trouble = df[((df['kcal_per_cup'].isna() & df['kcal_per_oz'].isna()) | df['item_oz'].isna()) & 
             ((df['kcal_per_kg'].isna() & df['kcal_per_lb'].isna()) | df['total_mass_lb'].isna()) &
             df['kcal_per_item'].isna()]

print(f'There are %d products out of %d which are missing required kcal/product values.' 
      % (len(trouble), len(df)))
# Out:
# There are 203 products out of 2071 which are missing required kcal/product values.

# %% [markdown]
# Let's see how many of these we could work with if we were willing to convert between mass and volume...
# We'll do calculations for kilocalories/product later, but for now we'll put a warning on these products.

# %%
annoying = trouble[(trouble['kcal_per_cup'].notnull() | trouble['kcal_per_oz'].notnull() | 
                    trouble['kcal_per_kg'].notnull() | trouble['kcal_per_lb'].notnull()) & 
                   (trouble['item_oz'].notnull() | trouble['total_mass_lb'].notnull())].copy()

print(f'We could salvage %d of the aforementioned %d products if we were willing to convert between mass and volume.' 
      % (len(annoying), len(trouble)))

df['conversion_warning'] = np.nan

df.loc[annoying.index, 'conversion_warning'] = 'kcal/product required a conversion between mass and volume'
# Out:
# We could salvage 141 of the aforementioned 203 products if we were willing to convert between mass and volume.

# %% [markdown]
# Good to know for later...

# %% [markdown]
# # Final clean up and save new tsv
# Get rid of columns we don't need anymore. Save as tsv because I think they look neater than csvs.

# %%
desired_cols = ['name', 'url', 'our_price', 'list_price', 'ingredients', '% protein min', '% fat min', '% fiber max', 
                '% misc components', '% moisture max', 'item number','weight', 'packaging type', 'food texture', 
                'brand', 'lifestage', 'food form', 'special diet', 'breed size', 'dimensions', 'small pet type', 
                'restricted availability', 'kcal_per_kg', 'kcal_per_lb', 'kcal_per_oz', 'kcal_per_cup', 'kcal_per_item',
                'item_volume_for_kcal', 'total_mass_lb', 'item_oz', 'item_count', 'moisture_warning', 
                'conversion_warning']

final_cols = [col for col in df.columns if col in desired_cols]

df_lite = df[final_cols]

df_lite.columns = df_lite.columns.str.replace(' ', '_')

df_lite.fillna(np.nan)

df_lite.to_csv(f'../data/interim/cleaned_chewy_data_{d}.txt', sep='\t', index=False)

# %%
df_lite
# Out:
#                                                    name  \
# 0     Hill's Prescription Diet c/d Multicare Urinary...
# 1     Hill's Prescription Diet k/d Kidney Care Veget...
# 2     Fancy Feast Classic Tender Liver & Chicken Fea...
# 3      Friskies Indoor Delights Dry Cat Food, 16-lb bag
# 4     Fancy Feast Classic Tender Beef Feast Canned C...
# 5     Meow Mix Tender Centers Salmon & White Meat Ch...
# 6     Hill's Prescription Diet k/d Kidney Care Chick...
# 7     American Journey Turkey & Chicken Recipe Grain...
# 8     Cat Chow Naturals Original Dry Cat Food, 13-lb...
# 9     Kitten Chow Nurture Muscle & Brain Development...
# 10    Hill's Prescription Diet c/d Multicare Urinary...
# 11    Iams ProActive Health Indoor Weight & Hairball...
# 12    Purina ONE Sensitive Skin & Stomach Dry Cat Fo...
# 13    Royal Canin Veterinary Diet Urinary SO Loaf In...
# 14    Royal Canin Veterinary Diet Urinary SO Morsels...
# 15    Fancy Feast Flaked Fish & Shrimp Feast Canned ...
# 16    9 Lives Daily Essentials with Chicken, Beef & ...
# 17    Purina ONE Healthy Kitten Formula Dry Cat Food...
# 18    Friskies Seafood Sensations Dry Cat Food, 16-l...
# 19    Royal Canin Veterinary Diet Hydrolyzed Protein...
# 20    Blue Buffalo Sensitive Stomach Chicken Recipe ...
# 21    Iams ProActive Health Healthy Adult Original w...
# 22    Fancy Feast Delights with Cheddar Grilled Chic...
# 23    Fancy Feast Classic Ocean Whitefish & Tuna Fea...
# 24               Kit & Kaboodle Dry Cat Food, 16-lb bag
# 25    Hill's Science Diet Adult Sensitive Stomach & ...
# 26    Hill's Prescription Diet c/d Multicare Urinary...
# 27    Friskies Tender & Crunchy Combo Dry Cat Food, ...
# 28    Rachael Ray Nutrish Natural Chicken & Brown Ri...
# 29    Fancy Feast Classic Salmon & Shrimp Feast Cann...
# ...                                                 ...
# 2041  Blue Buffalo Wilderness Salmon Recipe Grain-Fr...
# 2042  Fancy Feast Grilled Seafood Feast in Gravy Can...
# 2043  Blue Buffalo Wilderness Indoor Chicken Recipe ...
# 2044  Hill's Prescription Diet z/d Original Skin/Foo...
# 2045  Hill's Prescription Diet c/d Multicare Urinary...
# 2046  Iams ProActive Health Urinary Tract Health wit...
# 2047  Blue Buffalo Wilderness Kitten Chicken Recipe ...
# 2048  Fancy Feast Classic Savory Salmon Feast Canned...
# 2049  Fancy Feast Chunky Chicken Feast Canned Cat Fo...
# 2050  Friskies Gravy Sensations Pouch Favorites Wet ...
# 2051  Hill's Science Diet Adult Perfect Weight Chick...
# 2052  Purina ONE Tender Selects Blend with Real Salm...
# 2053  Hill's Science Diet Adult Indoor Chicken Recip...
# 2054  Friskies Classic Pate Turkey & Giblets Dinner ...
# 2055  Hill's Prescription Diet c/d Multicare Urinary...
# 2056  Cat Chow Sensitive Stomach Gentle Dry Cat Food...
# 2057  Fancy Feast Gravy Lovers Ocean Whitefish & Tun...
# 2058  Purina Pro Plan Focus Adult Urinary Tract Heal...
# 2059  Hill's Prescription Diet c/d Multicare Urinary...
# 2060  Fancy Feast Grilled Chicken Feast in Gravy Can...
# 2061  Hill's Prescription Diet c/d Multicare Urinary...
# 2062  Blue Buffalo Wilderness Chicken Recipe Grain-F...
# 2063  Fancy Feast Gravy Lovers Turkey Feast in Roast...
# 2064  Purina ONE Tender Selects Blend with Real Chic...
# 2065  Rachael Ray Nutrish Indoor Complete Chicken wi...
# 2066  Fancy Feast Gravy Lovers Chicken Feast in Gril...
# 2067  Fancy Feast Grilled Tuna Feast in Gravy Canned...
# 2068  Cat Chow Indoor Hairball & Healthy Weight Dry ...
# 2069   Meow Mix Original Choice Dry Cat Food, 22-lb bag
# 2070          Cat Chow Complete Dry Cat Food, 15-lb bag
#
#                                                     url  our_price  \
# 0     https://www.chewy.com/hills-prescription-diet-...      39.99
# 1     https://www.chewy.com/hills-prescription-diet-...      42.99
# 2     https://www.chewy.com/fancy-feast-classic-tend...      16.80
# 3     https://www.chewy.com/friskies-indoor-delights...       9.83
# 4     https://www.chewy.com/fancy-feast-classic-tend...      15.36
# 5     https://www.chewy.com/meow-mix-tender-centers-...      11.88
# 6     https://www.chewy.com/hills-prescription-diet-...      42.99
# 7     https://www.chewy.com/american-journey-turkey-...      29.99
# 8     https://www.chewy.com/cat-chow-naturals-origin...      14.99
# 9     https://www.chewy.com/kitten-chow-nurture-musc...      13.98
# 10    https://www.chewy.com/hills-prescription-diet-...      54.99
# 11    https://www.chewy.com/iams-proactive-health-in...      23.84
# 12    https://www.chewy.com/purina-one-sensitive-ski...      19.08
# 13    https://www.chewy.com/royal-canin-veterinary-d...      57.36
# 14    https://www.chewy.com/royal-canin-veterinary-d...      45.36
# 15    https://www.chewy.com/fancy-feast-flaked-fish-...      16.80
# 16    https://www.chewy.com/9-lives-daily-essentials...      12.98
# 17    https://www.chewy.com/purina-one-healthy-kitte...      20.82
# 18    https://www.chewy.com/friskies-seafood-sensati...      11.78
# 19    https://www.chewy.com/royal-canin-veterinary-d...      57.99
# 20    https://www.chewy.com/blue-buffalo-sensitive-s...      35.98
# 21    https://www.chewy.com/iams-proactive-health-he...      23.84
# 22    https://www.chewy.com/fancy-feast-delights-che...      15.36
# 23    https://www.chewy.com/fancy-feast-classic-ocea...      15.36
# 24    https://www.chewy.com/kit-kaboodle-dry-cat-foo...       9.98
# 25    https://www.chewy.com/hills-science-diet-adult...      44.99
# 26    https://www.chewy.com/hills-prescription-diet-...      44.99
# 27    https://www.chewy.com/friskies-tender-crunchy-...      11.78
# 28    https://www.chewy.com/rachael-ray-nutrish-natu...      19.97
# 29    https://www.chewy.com/fancy-feast-classic-salm...      16.80
# ...                                                 ...        ...
# 2041  https://www.chewy.com/blue-buffalo-wilderness-...      36.98
# 2042  https://www.chewy.com/fancy-feast-grilled-seaf...      15.60
# 2043  https://www.chewy.com/blue-buffalo-wilderness-...      36.98
# 2044  https://www.chewy.com/hills-prescription-diet-...      61.99
# 2045  https://www.chewy.com/hills-prescription-diet-...      44.99
# 2046  https://www.chewy.com/iams-proactive-health-ur...      23.84
# 2047  https://www.chewy.com/blue-buffalo-wilderness-...      22.98
# 2048  https://www.chewy.com/fancy-feast-classic-savo...      16.80
# 2049  https://www.chewy.com/fancy-feast-chunky-chick...      15.36
# 2050  https://www.chewy.com/friskies-gravy-sensation...      13.49
# 2051  https://www.chewy.com/hills-science-diet-adult...      44.99
# 2052  https://www.chewy.com/purina-one-tender-select...      24.41
# 2053  https://www.chewy.com/hills-science-diet-adult...      40.99
# 2054  https://www.chewy.com/friskies-classic-pate-tu...      12.96
# 2055  https://www.chewy.com/hills-prescription-diet-...      54.99
# 2056  https://www.chewy.com/cat-chow-sensitive-stoma...      13.98
# 2057  https://www.chewy.com/fancy-feast-gravy-lovers...      15.36
# 2058  https://www.chewy.com/purina-pro-plan-focus-ad...      23.28
# 2059  https://www.chewy.com/hills-prescription-diet-...      40.99
# 2060  https://www.chewy.com/fancy-feast-grilled-chic...      14.95
# 2061  https://www.chewy.com/hills-prescription-diet-...      39.99
# 2062  https://www.chewy.com/blue-buffalo-wilderness-...      36.98
# 2063  https://www.chewy.com/fancy-feast-gravy-lovers...      13.27
# 2064  https://www.chewy.com/purina-one-tender-select...      24.41
# 2065  https://www.chewy.com/rachael-ray-nutrish-indo...      19.97
# 2066  https://www.chewy.com/fancy-feast-gravy-lovers...      13.28
# 2067  https://www.chewy.com/fancy-feast-grilled-tuna...      15.36
# 2068  https://www.chewy.com/cat-chow-indoor-hairball...      13.98
# 2069  https://www.chewy.com/meow-mix-original-choice...      15.98
# 2070  https://www.chewy.com/cat-chow-complete-dry-ca...      13.98
#
#       list_price                                        ingredients  \
# 0            NaN  Water, Pork Liver, Chicken, Carrots, Wheat Glu...
# 1            NaN  Water, Pork Liver, Carrots, Tuna, Chicken, Ric...
# 2            NaN  Chicken Broth, Liver, Meat By-Products, Chicke...
# 3          11.99  Ground Yellow Corn, Corn Gluten Meal, Chicken ...
# 4          16.80  Beef, Meat Broth, Liver, Fish, Meat By-Product...
# 5          12.59  Whole Ground Corn, Chicken By-Product Meal, Co...
# 6            NaN  Water, Chicken, Pork Liver, Carrots, Rice, Ric...
# 7            NaN  Deboned Turkey, Turkey Meal, Chicken Meal, Tap...
# 8          15.99  Chicken, Corn Gluten Meal, Chicken By-Product ...
# 9          14.49  Chicken By-Product Meal, Corn Gluten Meal, Ric...
# 10           NaN  Pork By-Products, Water, Pork Liver, Chicken, ...
# 11         24.99  Chicken, Chicken By-Product Meal, Corn Grits, ...
# 12         24.99  Turkey, Chicken By-Product Meal, Rice Flour, C...
# 13           NaN  Water Sufficient For Processing, Pork By-Produ...
# 14           NaN  Water Sufficient For Processing, Pork By-Produ...
# 15           NaN  Ocean Fish, Fish Broth, Shrimp, Vegetable Oil,...
# 16         13.69  Whole Ground Corn, Chicken By-Product Meal, Co...
# 17         24.99  Chicken, Chicken By-Product Meal, Corn Gluten ...
# 18         11.99  Ground Yellow Corn, Corn Gluten Meal, Poultry ...
# 19           NaN  Brewers Rice, Hydrolyzed Soy Protein, Chicken ...
# 20           NaN  Deboned Chicken, Chicken Meal, Brown Rice, Oat...
# 21         24.99  Chicken, Chicken By-Product Meal, Ground Whole...
# 22         16.80  Poultry Broth, Chicken, Liver, Wheat Gluten, M...
# 23         16.80  Ocean Whitefish, Liver, Fish, Meat By-Products...
# 24           NaN  Ground Yellow Corn, Corn Gluten Meal, Soybean ...
# 25         46.99  Chicken, Brewers Rice, Corn Gluten Meal, Whole...
# 26           NaN  Chicken, Whole Grain Corn, Corn Gluten Meal, W...
# 27         11.99  Ground Yellow Corn, Corn Gluten Meal, Chicken ...
# 28           NaN  Chicken, Chicken Meal, Corn Gluten Meal, Brown...
# 29           NaN  Fish Broth, Salmon, Liver, Meat By-Products, T...
# ...          ...                                                ...
# 2041         NaN  Deboned Salmon, Chicken Meal, Pea Protein, Pea...
# 2042       16.80  Fish Broth, Ocean Fish, Wheat Gluten, Liver, M...
# 2043         NaN  Deboned Chicken, Chicken Meal, Pea Protein, Pe...
# 2044         NaN  Brewers Rice, Hydrolyzed Chicken Liver, Rice P...
# 2045         NaN  Ocean Fish, Brewers Rice, Cracked Pearled Barl...
# 2046       24.99  Chicken, Chicken By-Product Meal, Ground Whole...
# 2047         NaN  Deboned Chicken, Chicken Meal, Pea Protein, Ta...
# 2048         NaN  Salmon, Liver, Meat By-Products, Fish Broth, F...
# 2049       16.80  Chicken Broth, Chicken, Meat By-Products, Live...
# 2050         NaN  With Salmon In Gravy: Water Sufficient For Pro...
# 2051       46.99  Chicken, Brewers Rice, Corn Gluten Meal, Wheat...
# 2052       24.99  Salmon, Rice Flour, Corn Gluten Meal, Chicken ...
# 2053       41.99  Chicken, Whole Grain Wheat, Corn Gluten Meal, ...
# 2054       13.92  Meat By-Products, Water Sufficient for Process...
# 2055         NaN  Pork By-Products, Water, Pork Liver, Ocean Fis...
# 2056       15.99  Turkey By-product Meal, Corn Gluten Meal, Soyb...
# 2057       16.80  Fish Broth, Ocean Whitefish, Wheat Gluten, Liv...
# 2058         NaN  Water, Meat By-Products, Chicken, Wheat Gluten...
# 2059         NaN  Water, Pork Liver, Chicken, Carrots, Wheat Glu...
# 2060       16.80  Chicken Broth, Chicken, Liver, Wheat Gluten, M...
# 2061         NaN  Water, Pork Liver, Carrots, Chicken, Tuna, Whe...
# 2062         NaN  Deboned Chicken, Chicken Meal, Pea Protein, Ta...
# 2063       16.80  Poultry Broth, Turkey, Liver, Wheat Gluten, Me...
# 2064       24.99  Chicken, Rice Flour, Corn Gluten Meal, Chicken...
# 2065         NaN  Chicken, Chicken Meal, Brewer's Rice, Dried Pe...
# 2066       16.80  Poultry Broth, Chicken, Liver, Wheat Gluten, M...
# 2067       16.80  Fish Broth, Tuna, Wheat Gluten, Liver, Chicken...
# 2068       14.49  Chicken By-product Meal, Whole Grain Corn, Soy...
# 2069         NaN  Ground Yellow Corn, Corn Gluten Meal, Chicken ...
# 2070       14.49  Chicken By-Product Meal, Ground Yellow Corn, C...
#
#       %_protein_min  %_fat_min  %_fiber_max  %_moisture_max  item_number  ...  \
# 0               6.0        2.5         1.00            76.5      80485.0  ...
# 1               3.5        3.0         1.50            76.5      82586.0  ...
# 2              10.0        5.0         1.50            78.0      76027.0  ...
# 3              30.0        9.0         5.00            12.0      76407.0  ...
# 4              11.0        4.0         1.50            78.0      76035.0  ...
# 5              31.0       11.0         4.00            12.0      99977.0  ...
# 6               4.0        3.0         1.50            76.5      82584.0  ...
# 7              40.0       15.0         4.00            10.0     131581.0  ...
# 8              34.0       13.0         3.00            12.0     100144.0  ...
# 9              40.0       13.5         2.50            12.0     100176.0  ...
# 10              8.5        3.5         1.00            76.5      69865.0  ...
# 11             30.0       13.5         8.30            10.0      93653.0  ...
# 12             34.0       13.0         4.00            12.0      48649.0  ...
# 13             10.5        2.5         2.00            81.0      49990.0  ...
# 14              8.5        2.0         1.75            82.5      49989.0  ...
# 15             17.5        2.0         1.50            78.0      76055.0  ...
# 16             30.0        9.0         3.00            12.0      99879.0  ...
# 17             40.0       18.0         2.50            12.0      91700.0  ...
# 18             30.0       11.0         3.00            12.0      76416.0  ...
# 19             24.0       18.0         5.70             8.0      50317.0  ...
# 20             32.0       16.0         3.50             9.0      50765.0  ...
# 21             32.0       15.0         3.00            10.0      93642.0  ...
# 22             10.0        2.0         1.50            80.0      75960.0  ...
# 23             12.0        2.0         1.50            78.0      76045.0  ...
# 24             28.0       10.0         3.00            12.0     100160.0  ...
# 25             29.0       17.0         3.00            10.0      48888.0  ...
# 26             30.0       13.0         1.60            11.0      69863.0  ...
# 27             30.0       11.0         3.00            12.0      76403.0  ...
# 28             34.0       14.0         4.00             9.0      77993.0  ...
# 29             11.0        4.0         1.50            78.0      76022.0  ...
# ...             ...        ...          ...             ...          ...  ...
# 2041           40.0       18.0         4.00             9.0      84281.0  ...
# 2042           11.0        2.0         1.50            80.0      76081.0  ...
# 2043           38.0       16.0         6.00             9.0      84976.0  ...
# 2044           29.0       10.5         4.50             9.0      69817.0  ...
# 2045           30.0       13.0         2.00            11.0      80480.0  ...
# 2046           32.0       15.0         1.70            10.0     149484.0  ...
# 2047           40.0       20.0         3.50             9.0      51555.0  ...
# 2048           11.0        4.0         1.50            78.0      76030.0  ...
# 2049           11.0        4.0         1.50            78.0      76065.0  ...
# 2050           10.0        2.0         1.50            80.0      76433.0  ...
# 2051           36.0        8.5        10.00             8.0      74244.0  ...
# 2052           34.0       13.0         2.00            12.0      91798.0  ...
# 2053           31.0       13.0        12.00             8.0      48900.0  ...
# 2054           10.0        5.0         1.00            78.0      76202.0  ...
# 2055            8.5        3.0         1.00            76.5      69857.0  ...
# 2056           34.0       11.0         5.00            12.0     100118.0  ...
# 2057            9.0        2.0         1.50            82.0      75976.0  ...
# 2058           12.0        3.5         0.20            78.0      67913.0  ...
# 2059            6.0        2.5         1.00            76.5      80487.0  ...
# 2060           11.0        2.0         1.50            80.0      76073.0  ...
# 2061            6.5        3.0         2.00            76.5      80489.0  ...
# 2062           40.0       18.0         4.00             9.0      46918.0  ...
# 2063            9.0        2.0         1.50            82.0      75974.0  ...
# 2064           34.0       13.0         2.00            12.0      91682.0  ...
# 2065           34.0       12.0         8.00             9.0     108512.0  ...
# 2066            9.0        2.0         1.50            82.0      75964.0  ...
# 2067           11.0        2.0         1.50            80.0      76091.0  ...
# 2068           30.0        9.5         4.70            12.0     173768.0  ...
# 2069           31.0       11.0         4.00            12.0      99967.0  ...
# 2070           32.0       12.0         3.00            12.0     173769.0  ...
#
#       kcal_per_lb kcal_per_oz kcal_per_cup kcal_per_item item_volume_for_kcal  \
# 0             NaN        69.0          NaN         69.00                  NaN
# 1             NaN        77.0          NaN         77.00                  NaN
# 2             NaN         NaN          NaN         97.00                  NaN
# 3             NaN         NaN        364.0           NaN                  NaN
# 4             NaN         NaN          NaN         92.00                  NaN
# 5             NaN         NaN        328.0           NaN                  NaN
# 6             NaN        70.0          NaN         70.00                  NaN
# 7             NaN         NaN        395.0           NaN                  NaN
# 8             NaN         NaN        398.0           NaN                  NaN
# 9             NaN         NaN        414.0           NaN                  NaN
# 10            NaN       163.0          NaN        163.00                  NaN
# 11            NaN         NaN        302.0           NaN                  NaN
# 12            NaN         NaN        430.0           NaN                  NaN
# 13            NaN       135.0          NaN        135.00                  NaN
# 14            NaN        65.0          NaN         65.00                  NaN
# 15            NaN         NaN          NaN         87.00                  NaN
# 16            NaN         NaN        306.0           NaN                  NaN
# 17            NaN         NaN        462.0           NaN                  NaN
# 18            NaN         NaN        388.0           NaN                  NaN
# 19            NaN         NaN        351.0           NaN                  NaN
# 20            NaN         NaN        422.0           NaN                  NaN
# 21            NaN         NaN        399.0           NaN                  NaN
# 22            NaN         NaN          NaN         71.00                  NaN
# 23            NaN         NaN          NaN         85.00                  NaN
# 24            NaN         NaN        404.0           NaN                  NaN
# 25            NaN         NaN        524.0           NaN                  NaN
# 26            NaN         NaN        349.0           NaN                  NaN
# 27            NaN         NaN        389.0           NaN                  NaN
# 28            NaN         NaN        386.0           NaN                  NaN
# 29            NaN         NaN          NaN         92.00                  NaN
# ...           ...         ...          ...           ...                  ...
# 2041          NaN         NaN        438.0           NaN                  NaN
# 2042          NaN         NaN          NaN         70.00                  NaN
# 2043          NaN         NaN        410.0           NaN                  NaN
# 2044          NaN         NaN        408.0           NaN                  NaN
# 2045          NaN         NaN        382.0           NaN                  NaN
# 2046          NaN         NaN        387.0           NaN                  NaN
# 2047          NaN         NaN        457.0           NaN                  NaN
# 2048          NaN         NaN          NaN         87.00                  NaN
# 2049          NaN         NaN          NaN         95.00                  NaN
# 2050          NaN        74.0          NaN         74.00                  NaN
# 2051          NaN         NaN        300.0           NaN                  NaN
# 2052          NaN         NaN        360.0           NaN                  NaN
# 2053          NaN         NaN        319.0           NaN                  NaN
# 2054          NaN       416.0          NaN        416.00                  NaN
# 2055          NaN       169.0          NaN        169.00                  NaN
# 2056          NaN         NaN        402.0           NaN                  NaN
# 2057          NaN         NaN          NaN         66.00                  NaN
# 2058          NaN        25.1          NaN           NaN                  NaN
# 2059          NaN        69.0          NaN         69.00                  NaN
# 2060          NaN         NaN          NaN         71.00                  NaN
# 2061          NaN        67.0          NaN         67.00                  NaN
# 2062          NaN         NaN        443.0           NaN                  NaN
# 2063          NaN         NaN          NaN         22.59                  NaN
# 2064          NaN         NaN        366.0           NaN                  NaN
# 2065          NaN         NaN        354.0           NaN                  NaN
# 2066          NaN         NaN          NaN         67.00                  NaN
# 2067          NaN         NaN          NaN         70.00                  NaN
# 2068          NaN         NaN        358.0           NaN                  NaN
# 2069          NaN         NaN        308.0           NaN                  NaN
# 2070          NaN         NaN        405.0           NaN                  NaN
#
#      total_mass_lb item_oz item_count          moisture_warning  \
# 0              NaN     2.9       24.0  % moisture max estimated
# 1              NaN     2.9       24.0  % moisture max estimated
# 2              NaN     3.0       24.0                       NaN
# 3             16.0     NaN        1.0                       NaN
# 4              NaN     3.0       24.0                       NaN
# 5             13.5     NaN        1.0                       NaN
# 6              NaN     2.9       24.0  % moisture max estimated
# 7             12.0     NaN        1.0                       NaN
# 8             13.0     NaN        1.0                       NaN
# 9             14.0     NaN        1.0                       NaN
# 10             NaN     5.5       24.0  % moisture max estimated
# 11            16.0     NaN        1.0                       NaN
# 12            16.0     NaN        1.0                       NaN
# 13             NaN     5.8       24.0                       NaN
# 14             NaN     3.0       24.0                       NaN
# 15             NaN     3.0       24.0                       NaN
# 16            20.0     NaN        1.0                       NaN
# 17            16.0     NaN        1.0                       NaN
# 18            16.0     NaN        1.0                       NaN
# 19             7.7     NaN        1.0                       NaN
# 20            15.0     NaN        1.0                       NaN
# 21            16.0     NaN        1.0                       NaN
# 22             NaN     3.0       24.0                       NaN
# 23             NaN     3.0       24.0                       NaN
# 24            16.0     NaN        1.0                       NaN
# 25            15.5     NaN        1.0                       NaN
# 26             8.5     NaN        1.0  % moisture max estimated
# 27            16.0     NaN        1.0                       NaN
# 28            14.0     NaN        1.0                       NaN
# 29             NaN     3.0       24.0                       NaN
# ...            ...     ...        ...                       ...
# 2041          11.0     NaN        1.0                       NaN
# 2042           NaN     3.0       24.0                       NaN
# 2043          11.0     NaN        1.0                       NaN
# 2044           8.5     NaN        1.0                       NaN
# 2045           8.5     NaN        1.0  % moisture max estimated
# 2046          16.0     NaN        1.0                       NaN
# 2047           5.0     NaN        1.0                       NaN
# 2048           NaN     3.0       24.0                       NaN
# 2049           NaN     3.0       24.0                       NaN
# 2050           NaN     3.0       24.0                       NaN
# 2051          15.0     NaN        1.0                       NaN
# 2052          16.0     NaN        1.0                       NaN
# 2053          15.5     NaN        1.0                       NaN
# 2054           NaN     5.5       24.0                       NaN
# 2055           NaN     5.5       24.0  % moisture max estimated
# 2056          13.0     NaN        1.0                       NaN
# 2057           NaN     3.0       24.0                       NaN
# 2058           NaN     3.0       24.0                       NaN
# 2059           NaN     2.9       24.0  % moisture max estimated
# 2060           NaN     3.0       24.0                       NaN
# 2061           NaN     2.9       24.0  % moisture max estimated
# 2062          12.0     NaN        1.0                       NaN
# 2063           NaN     3.0       24.0                       NaN
# 2064          16.0     NaN        1.0                       NaN
# 2065          14.0     NaN        1.0                       NaN
# 2066           NaN     3.0       24.0                       NaN
# 2067           NaN     3.0       24.0                       NaN
# 2068          15.0     NaN        1.0                       NaN
# 2069          22.0     NaN        1.0                       NaN
# 2070          15.0     NaN        1.0                       NaN
#
#                                      conversion_warning
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25    kcal/product required a conversion between mas...
# 26    kcal/product required a conversion between mas...
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 2041                                                NaN
# 2042                                                NaN
# 2043                                                NaN
# 2044  kcal/product required a conversion between mas...
# 2045  kcal/product required a conversion between mas...
# 2046                                                NaN
# 2047                                                NaN
# 2048                                                NaN
# 2049                                                NaN
# 2050                                                NaN
# 2051  kcal/product required a conversion between mas...
# 2052                                                NaN
# 2053  kcal/product required a conversion between mas...
# 2054                                                NaN
# 2055                                                NaN
# 2056                                                NaN
# 2057                                                NaN
# 2058                                                NaN
# 2059                                                NaN
# 2060                                                NaN
# 2061                                                NaN
# 2062                                                NaN
# 2063                                                NaN
# 2064                                                NaN
# 2065                                                NaN
# 2066                                                NaN
# 2067                                                NaN
# 2068                                                NaN
# 2069                                                NaN
# 2070                                                NaN
#
# [2071 rows x 33 columns]
