# %%
from datetime import date
import pandas as pd
import sys
sys.path.append('../src')
import data.clean as clean
import numpy as np

# %% [markdown]
# # Read external data into a pandas df

# %%
today = date.today()
d = today.strftime('%Y_%m_%d')
#d = '2020_11_25'

df = pd.read_csv(f'../data/external/raw_chewy_data_{d}.csv')

# %% [markdown]
# # Clean data
#
# ## Unpack attribute and guarenteed analysis (GA) dictionaries
# import reAttribute information and guarenteed analysis (GA) information are stored as dictionaries in their columns. This is because different products have different fields/numbers of fields in these tables. So first things first, expand those two columns.

# %%
# help(clean.dict_col_to_cols)

df = clean.dict_col_to_cols(df=df, col='ga_dict', ga=True)
df = clean.dict_col_to_cols(df=df, col='attr_dict', ga=False)

# %% [markdown]
# ## Fill guarenteed analysis columns missing critical statistics
#
# It is mandatory that cat food manufacturers report % protein min, % fat min, and % fiber max in their guarenteed analysis. So it's likely that when there isn't a value for one of these macros, but there is a value for a very similarly named macro, a typo has been made. So we need to fill empty macro values with the values most likely to be correct.

# %%
df['% protein min'] = df['% protein min'].fillna(df['% protein']).fillna(df['% protein max'])
df['% fat min'] = df['% fat min'].fillna(df['% fat']).fillna(df['% fat max'])
df['% fiber max'] = df['% fiber max'].fillna(df['% fiber']).fillna(df['% fiber min'])
df['% moisture max'] = df['% moisture max'].fillna(df['% moisture']).fillna(df['% moisture min'])

# df = df.dropna(thresh = df.shape[0] * 0.5, how = 'all', axis = 1)

# %% [markdown]
# ## Add up percentages of misc. guarenteed analysis componenets
# There are so many miscellaneous compounds that are included in only a handful of the products' guarenteed analysis. We want the percent values for these compounds, because they will help us calculate % carbohydrates later, but we don't need them individually. So we want to add up the columns that start with '%' and are not protein, fat, fiber, moisture, or carbohydrate (a few products have this value, but we will be calculating it for all products). If the sum of these columns is 100% or greater, we know something has gone terribly wrong (I found a typo...) so we will set that value to nan.

# %%
macros = ('protein', 'fat', 'fiber', 'moisture', 'carbohydrate')

misc_components = [col for col in df if '%' in col and not any(macro in col for macro in macros)]

df['% misc components'] = df[misc_components].sum(axis=1)

df.loc[df['% misc components'] >= 100, '% misc components'] = np.nan

# %% [markdown]
# ## Extract kilocalories/mass or kilocalories/volume
# The calories column contains information about the number of kilocalories per unit mass or volume of food. However, the units are not consistent, and often multiple values are reported. So we can pull out the kcal/unit mass for dry food, and the kcal/unit volume for wet food (this is because total product size is given in mass for dry food and volume for wet food, and we'd like to eventually calculate U.S. dollar per kcal).

# %%
# help(clean.get_unit_val_col)

# kcal/unit of mass:
df = clean.get_unit_val_col(df, column_name = 'calories',
                  col_split_regex = '(?<!/) (?=\d)|,|;|:',
                  unit_name = 'kcal_per_kg',
                  unit_regex = 'kcal.*kg')

df = clean.get_unit_val_col(df, column_name = 'calories',
                  col_split_regex = '(?<!/) (?=\d)|,|;|:',
                  unit_name = 'kcal_per_lb',
                  unit_regex = 'kcal.*lb')

# kcal/unit of volume:
df = clean.get_unit_val_col(df, column_name = 'calories',
                  col_split_regex = '(?<!/) (?=\d)|,|;|:',
                  unit_name = 'kcal_per_oz',
                  unit_regex = 'kcal.*oz|kcal.*ounce')

df = clean.get_unit_val_col(df, column_name = 'calories',
                  col_split_regex = '(?<!/) (?=\d)|,|;|:',
                  unit_name = 'kcal_per_cup',
                  unit_regex = 'kcal.*cup')

# kcal/item (kcal in a single can, pouch, etc.)
df = clean.get_unit_val_col(df, column_name = 'calories',
                  col_split_regex = '(?<!/) (?=\d)|,|;|:',
                  unit_name = 'kcal_per_item',
                  unit_regex = 'kcal.*can|kcal.*pouch|kcl.*pouch|kcal.*unit|kcal.*bowl|kcal.*tray|kcal.*container|kcal.*serving|kcal.*tub|kcal.*pack',
                  clear_inconsistent_rows = False,
                  get_denom_col = True,
                  denom_name = 'item_volume_for_kcal',
                  denom_regex = '((?<=\/).*?\d+\.?\d+)')

# %% [markdown]
# ## Extract item mass, volume, and/or count
# For dry food we need the total mass of the bag, for wet food we need the total volume of the can/item unit and the number of cans/item units.

# %%
# number of lbs per item
df = clean.get_unit_val_col(df, column_name = 'name',
                  col_split_regex = ',',
                  unit_name = 'total_mass_lb',
                  unit_regex = 'lb|pound|Pound')

# if no number lbs found, get that value from the weight attribute 
# DO NOT DO THIS WEIGHTS ARE NOT ALL IN LBS
# df['total_mass_lb'] = df['total_mass_lb'].fillna(df['weight'])

# number of ounces per item
df = clean.get_unit_val_col(df, column_name = 'name',
                  col_split_regex = ',',
                  unit_name = 'item_oz',
                  unit_regex = 'oz|ounce')

# number of items
df = clean.get_unit_val_col(df, column_name = 'name',
                  col_split_regex = ',',
                  unit_name = 'item_count',
                  unit_regex = 'case of')

# if no number of items specified, set item_count to 1
df['item_count'] = df['item_count'].fillna(1)

# %% [markdown]
# # Filling values and adding warnings
# ## Nutritional info
# For nutritional information, we need to know AT LEAST the % protein min, % fat min, and % moisture. % fiber max should also be provided. To calculate the cost per kilocalorie, we need the prouct price, and the kilocalories per product.

# %%
missing_ga = df[df['% protein min'].isna() | df['% fat min'].isna() | df['% fiber max'].isna()]

print(f'There are %d products out of %d which are missing protein, fat, or fiber info.' 
      % (len(missing_ga), len(df)))

missing_moisture = df[df['% protein min'].notnull() & df['% fat min'].notnull() & df['% fiber max'].notnull() & df['% moisture max'].isna()]

print(f'There are %d products out of %d which have all protein, fat, and fiber info, but not moisture.' 
      % (len(missing_moisture), len(df)))
# Out:
# There are 16 products out of 2071 which are missing protein, fat, or fiber info.
# There are 49 products out of 2071 which have all protein, fat, and fiber info, but not moisture.

# %% [markdown]
# The average wet cat food and the average dry cat food are supposed to have 75-78% and 10-12% moisture max, respectively (https://www.petfoodinstitute.org/the-whole-bowl/z-pet-food-4-things-know-dry-pet-food/).
# We could assign those moisture values to the foods that are missing moisture information but have all the other nutrient values.
#
# Out of curiosity, do those values reflect the average moisture for wet and dry cat food in this data?

# %%
wet_mean = df[df['food form'].str.contains('wet food', na=False)]['% moisture max'].mean()

dry_mean = df[df['food form'].str.contains('dry food', na=False)]['% moisture max'].mean()

print(f'In this data, wet food has a mean percent moisture max of %d percent, \
and dry food has a mean percent moisture max of %d percent.' 
      % (wet_mean, dry_mean))
# Out:
# In this data, wet food has a mean percent moisture max of 80 percent, and dry food has a mean percent moisture max of 9 percent.

# %% [markdown]
# ### Assuming moisture content
# For all products that have values for protein, fat, and fiber, but are missing a value for moisture, we can fill in the moisture value with an estimate based on if the food is wet or dry. But if we do this, we should add a warning column stating that this value was estimated.

# %%
df['moisture_warning'] = np.nan

df.loc[df['food form'].str.contains('wet food') 
       & df['% protein min'].notnull() 
       & df['% fat min'].notnull() 
       & df['% fiber max'].notnull() 
       & df['% moisture max'].isna(), 
       ['% moisture max', 'moisture_warning']] = [76.5, '% moisture max estimated']

df.loc[df['food form'].str.contains('dry food') 
       & df['% protein min'].notnull() 
       & df['% fat min'].notnull() 
       & df['% fiber max'].notnull() 
       & df['% moisture max'].isna(), 
       ['% moisture max', 'moisture_warning']] = [11, '% moisture max estimated']

# %% [markdown]
# ## Kilocalories/product
# Calculating kilocalories per product is a bit trickier. We need to make sure we're not mistaking mass with volume. When wet food is measured in ounces, they are fluid ounces. But if we're given the calorie content of a wet food only in kcal/kg, we can't convert fluid ounces to kilograms, because we don't know the density of the wet food (though most wet food is ~78% water).
#
# So for each product we need price, and either:
#
# 1. kcal/unit of volume (cups or ounces)
# 2. item volume (cups or ounces)
#
# OR
#
# 1. kcal/unit of mass (kg or lb)
# 2. item mass (kg or lb)
#
# OR
#
# 1. kcal/item
# 2. item count

# %%
trouble = df[((df['kcal_per_cup'].isna() & df['kcal_per_oz'].isna()) | df['item_oz'].isna()) & 
             ((df['kcal_per_kg'].isna() & df['kcal_per_lb'].isna()) | df['total_mass_lb'].isna()) &
             df['kcal_per_item'].isna()]

print(f'There are %d products out of %d which are missing required kcal/product values.' 
      % (len(trouble), len(df)))
# Out:
# There are 203 products out of 2071 which are missing required kcal/product values.

# %% [markdown]
# Let's see how many of these we could work with if we were willing to convert between mass and volume...
# We'll do calculations for kilocalories/product later, but for now we'll put a warning on these products.

# %%
annoying = trouble[(trouble['kcal_per_cup'].notnull() | trouble['kcal_per_oz'].notnull() | 
                    trouble['kcal_per_kg'].notnull() | trouble['kcal_per_lb'].notnull()) & 
                   (trouble['item_oz'].notnull() | trouble['total_mass_lb'].notnull())].copy()

print(f'We could salvage %d of the aforementioned %d products if we were willing to convert between mass and volume.' 
      % (len(annoying), len(trouble)))

df['conversion_warning'] = np.nan

df.loc[annoying.index, 'conversion_warning'] = 'kcal/product required a conversion between mass and volume'
# Out:
# We could salvage 141 of the aforementioned 203 products if we were willing to convert between mass and volume.

# %% [markdown]
# Good to know for later...

# %% [markdown]
# # Final clean up and save new tsv
# Get rid of columns we don't need anymore. Save as tsv because I think they look neater than csvs.

# %%
desired_cols = ['name', 'url', 'our_price', 'list_price', 'ingredients', '% protein min', '% fat min', '% fiber max', 
                '% misc components', '% moisture max', 'item number','weight', 'packaging type', 'food texture', 
                'brand', 'lifestage', 'food form', 'special diet', 'breed size', 'dimensions', 'small pet type', 
                'restricted availability', 'kcal_per_kg', 'kcal_per_lb', 'kcal_per_oz', 'kcal_per_cup', 'kcal_per_item',
                'item_volume_for_kcal', 'total_mass_lb', 'item_oz', 'item_count', 'moisture_warning', 
                'conversion_warning']

final_cols = [col for col in df.columns if col in desired_cols]

df_lite = df[final_cols]

df_lite.columns = df_lite.columns.str.replace(' ', '_')

df_lite.fillna(np.nan)

df_lite.to_csv(f'../data/interim/cleaned_chewy_data_{d}.txt', sep='\t', index=False)

# %%
df_lite
# Out:
#                                                    name  \
# 0     Hill's Prescription Diet k/d Kidney Care Veget...
# 1     Fancy Feast Classic Tender Beef Feast Canned C...
# 2     Fancy Feast Classic Tender Liver & Chicken Fea...
# 3     Hill's Prescription Diet c/d Multicare Urinary...
# 4      Friskies Indoor Delights Dry Cat Food, 16-lb bag
# 5     American Journey Turkey & Chicken Recipe Grain...
# 6     Cat Chow Naturals Original Dry Cat Food, 13-lb...
# 7     Meow Mix Tender Centers Salmon & White Meat Ch...
# 8     Iams ProActive Health Indoor Weight & Hairball...
# 9     Hill's Prescription Diet c/d Multicare Urinary...
# 10    Purina ONE Sensitive Skin & Stomach Dry Cat Fo...
# 11    Royal Canin Veterinary Diet Urinary SO Loaf In...
# 12    Kitten Chow Nurture Muscle & Brain Development...
# 13    Hill's Prescription Diet k/d Kidney Care Chick...
# 14    Purina ONE Healthy Kitten Formula Dry Cat Food...
# 15    Friskies Seafood Sensations Dry Cat Food, 16-l...
# 16    Iams ProActive Health Healthy Adult Original w...
# 17    Royal Canin Veterinary Diet Hydrolyzed Protein...
# 18    Blue Buffalo Sensitive Stomach Chicken Recipe ...
# 19    Fancy Feast Delights with Cheddar Grilled Chic...
# 20    Fancy Feast Classic Ocean Whitefish & Tuna Fea...
# 21    Royal Canin Veterinary Diet Urinary SO Morsels...
# 22    Hill's Science Diet Adult Sensitive Stomach & ...
# 23    Fancy Feast Classic Salmon & Shrimp Feast Cann...
# 24    Friskies Tender & Crunchy Combo Dry Cat Food, ...
# 25    Hill's Prescription Diet c/d Multicare Urinary...
# 26    Taste of the Wild Rocky Mountain Grain-Free Dr...
# 27    Fancy Feast Grilled Salmon Feast in Gravy Cann...
# 28    Fancy Feast Gourmet Savory Chicken & Turkey Dr...
# 29    Purina Pro Plan Savor Adult White Meat Chicken...
# ...                                                 ...
# 2041  FirstMate Wild Tuna Formula Limited Ingredient...
# 2042  Scrumptious From Scratch Tuna Dinner In Gravy ...
# 2043  Almo Nature Daily Complete Tuna Dinner with Sh...
# 2044  Dave's Pet Food Cat’s Meow Beef with Duck Dinn...
# 2045  Almo Nature HQS Natural Ham with Parmesan in B...
# 2046  Now Fresh Grain-Free Wild Salmon Pate Wet Cat ...
# 2047  Redbarn Filets Salmon & Shrimp Entrée Flaked i...
# 2048  Almo Nature HQS Natural Mixed Seafood in Broth...
# 2049  Royal Canin Veterinary Diet Adult Dry Cat Food...
# 2050  Lafeber EmerAid Sustain HDN Senior Cat Food, 3...
# 2051  Tuscan Natural Harvest Turkey & Chicken Dry Ca...
# 2052  Almo Nature HQS Natural Ham with Turkey in Bro...
# 2053  Tender & True Turkey & Brown Rice Recipe Dry C...
# 2054  Almo Nature HQS Natural Grilled Turkey in Brot...
# 2055  Pet Wellbeing Premium Holistic Formula Dry Cat...
# 2056  FirstMate 50/50 Turkey & Tuna Formula Grain-Fr...
# 2057  Scrumptious From Scratch Tuna & Oceanfish Dinn...
# 2058  AvoDerm Natural Grain-Free Chicken & Duck Reci...
# 2059  Scrumptious From Scratch Tuna & Chicken Dinner...
# 2060  Snappy Tom Naturals Tuna with Mackerel Cat Foo...
# 2061  Scrumptious From Scratch Chicken & Pumpkin Din...
# 2062  Blackwood Chicken & Salmon With Pumpkin Grain-...
# 2063  Tuscan Natural Simply Pure Ocean Extreme Grain...
# 2064  Snappy Tom Ultimates Tender Chicken in Broth C...
# 2065  Atta Cat Chicken & Salmon Flavor Dry Cat Food,...
# 2066  Almo Nature Daily Complete Tuna Dinner with Ma...
# 2067  Scrumptious From Scratch Chicken & Salmon Dinn...
# 2068  Evolve Salmon & Sweet Potato Stew in Gravy Gra...
# 2069  Tiki Cat Raw Turkey with Turkey Bone Broth Gra...
# 2070  Merrick Purrfect Bistro Mixed Seafood Grill Re...
#
#                                                     url  our_price  \
# 0     https://www.chewy.com/hills-prescription-diet-...      42.99
# 1     https://www.chewy.com/fancy-feast-classic-tend...      15.36
# 2     https://www.chewy.com/fancy-feast-classic-tend...      16.80
# 3     https://www.chewy.com/hills-prescription-diet-...      39.99
# 4     https://www.chewy.com/friskies-indoor-delights...       9.83
# 5     https://www.chewy.com/american-journey-turkey-...      29.99
# 6     https://www.chewy.com/cat-chow-naturals-origin...      14.99
# 7     https://www.chewy.com/meow-mix-tender-centers-...      11.88
# 8     https://www.chewy.com/iams-proactive-health-in...      23.84
# 9     https://www.chewy.com/hills-prescription-diet-...      54.99
# 10    https://www.chewy.com/purina-one-sensitive-ski...      19.08
# 11    https://www.chewy.com/royal-canin-veterinary-d...      57.36
# 12    https://www.chewy.com/kitten-chow-nurture-musc...      13.98
# 13    https://www.chewy.com/hills-prescription-diet-...      42.99
# 14    https://www.chewy.com/purina-one-healthy-kitte...      20.82
# 15    https://www.chewy.com/friskies-seafood-sensati...      11.78
# 16    https://www.chewy.com/iams-proactive-health-he...      23.84
# 17    https://www.chewy.com/royal-canin-veterinary-d...      57.99
# 18    https://www.chewy.com/blue-buffalo-sensitive-s...      35.98
# 19    https://www.chewy.com/fancy-feast-delights-che...      15.36
# 20    https://www.chewy.com/fancy-feast-classic-ocea...      15.36
# 21    https://www.chewy.com/royal-canin-veterinary-d...      45.36
# 22    https://www.chewy.com/hills-science-diet-adult...      44.99
# 23    https://www.chewy.com/fancy-feast-classic-salm...      16.80
# 24    https://www.chewy.com/friskies-tender-crunchy-...      11.78
# 25    https://www.chewy.com/hills-prescription-diet-...      44.99
# 26    https://www.chewy.com/taste-wild-rocky-mountai...      30.99
# 27    https://www.chewy.com/fancy-feast-grilled-salm...      16.80
# 28    https://www.chewy.com/fancy-feast-gourmet-savo...      24.78
# 29    https://www.chewy.com/purina-pro-plan-savor-ad...      23.28
# ...                                                 ...        ...
# 2041  https://www.chewy.com/firstmate-wild-tuna-form...      55.19
# 2042  https://www.chewy.com/scrumptious-from-scratch...      11.89
# 2043  https://www.chewy.com/almo-nature-daily-comple...      14.28
# 2044  https://www.chewy.com/daves-pet-food-cats-meow...      39.99
# 2045  https://www.chewy.com/almo-nature-hqs-natural-...      42.96
# 2046  https://www.chewy.com/now-fresh-grain-free-wil...      82.31
# 2047  https://www.chewy.com/redbarn-filets-salmon-sh...      19.08
# 2048  https://www.chewy.com/almo-nature-natural-mixe...      32.71
# 2049  https://www.chewy.com/royal-canin-veterinary-d...      87.99
# 2050  https://www.chewy.com/lafeber-emeraid-sustain-...      14.99
# 2051  https://www.chewy.com/tuscan-natural-harvest-t...      57.82
# 2052  https://www.chewy.com/almo-nature-hqs-natural-...      42.96
# 2053  https://www.chewy.com/tender-true-turkey-brown...      11.99
# 2054  https://www.chewy.com/almo-nature-hqs-natural-...      42.96
# 2055  https://www.chewy.com/pet-wellbeing-premium-ho...      64.99
# 2056  https://www.chewy.com/firstmate-5050-turkey-tu...      55.19
# 2057  https://www.chewy.com/scrumptious-from-scratch...      11.89
# 2058  https://www.chewy.com/avoderm-natural-grain-fr...      35.76
# 2059  https://www.chewy.com/scrumptious-from-scratch...      11.89
# 2060  https://www.chewy.com/snappy-tom-naturals-tuna...      20.41
# 2061  https://www.chewy.com/scrumptious-from-scratch...      17.30
# 2062  https://www.chewy.com/blackwood-chicken-salmon...      42.96
# 2063  https://www.chewy.com/tuscan-natural-simply-pu...      24.08
# 2064  https://www.chewy.com/snappy-tom-ultimates-ten...      23.88
# 2065  https://www.chewy.com/atta-cat-chicken-salmon-...      23.11
# 2066  https://www.chewy.com/almo-nature-daily-comple...      15.00
# 2067  https://www.chewy.com/scrumptious-from-scratch...      17.88
# 2068  https://www.chewy.com/evolve-salmon-sweet-pota...      24.95
# 2069  https://www.chewy.com/tiki-cat-raw-turkey-turk...      49.97
# 2070  https://www.chewy.com/merrick-purrfect-bistro-...      42.96
#
#       list_price                                        ingredients  \
# 0            NaN  Water, Pork Liver, Carrots, Tuna, Chicken, Ric...
# 1          16.80  Beef, Meat Broth, Liver, Fish, Meat By-Product...
# 2            NaN  Chicken Broth, Liver, Meat By-Products, Chicke...
# 3            NaN  Water, Pork Liver, Chicken, Carrots, Wheat Glu...
# 4          11.99  Ground Yellow Corn, Corn Gluten Meal, Chicken ...
# 5            NaN  Deboned Turkey, Turkey Meal, Chicken Meal, Tap...
# 6          15.99  Chicken, Corn Gluten Meal, Chicken By-Product ...
# 7          12.59  Whole Ground Corn, Chicken By-Product Meal, Co...
# 8          24.99  Chicken, Chicken By-Product Meal, Corn Grits, ...
# 9            NaN  Pork By-Products, Water, Pork Liver, Chicken, ...
# 10         24.99  Turkey, Chicken By-Product Meal, Rice Flour, C...
# 11           NaN  Water Sufficient For Processing, Pork By-Produ...
# 12         14.49  Chicken By-Product Meal, Corn Gluten Meal, Ric...
# 13           NaN  Water, Chicken, Pork Liver, Carrots, Rice, Ric...
# 14         24.99  Chicken, Chicken By-Product Meal, Corn Gluten ...
# 15         11.99  Ground Yellow Corn, Corn Gluten Meal, Poultry ...
# 16         24.99  Chicken, Chicken By-Product Meal, Ground Whole...
# 17           NaN  Brewers Rice, Hydrolyzed Soy Protein, Chicken ...
# 18           NaN  Deboned Chicken, Chicken Meal, Brown Rice, Oat...
# 19         16.80  Poultry Broth, Chicken, Liver, Wheat Gluten, M...
# 20         16.80  Ocean Whitefish, Liver, Fish, Meat By-Products...
# 21           NaN  Water Sufficient For Processing, Pork By-Produ...
# 22         46.99  Chicken, Brewers Rice, Corn Gluten Meal, Whole...
# 23           NaN  Fish Broth, Salmon, Liver, Meat By-Products, T...
# 24         11.99  Ground Yellow Corn, Corn Gluten Meal, Chicken ...
# 25           NaN  Chicken, Whole Grain Corn, Corn Gluten Meal, W...
# 26           NaN  Chicken Meal, Peas, Sweet Potatoes, Chicken Fa...
# 27           NaN  Fish Broth, Salmon, Liver, Wheat Gluten, Meat ...
# 28         26.99  Ground Rice, Poultry By-Product Meal, Corn Glu...
# 29           NaN  Water Sufficient for Processing, Chicken, Whea...
# ...          ...                                                ...
# 2041         NaN  Tuna, Water Sufficient for Processing, Potato,...
# 2042         NaN  Tuna, Tuna Broth, Carrots, Green Peas, Sunflow...
# 2043         NaN  Tuna, Fish Broth, Shrimp, Tapioca Starch, Sunf...
# 2044         NaN  Beef, Beef Broth, Beef Liver, Duck, Tricalcium...
# 2045         NaN  Ham, Water Sufficient For Processing, Cheese (...
# 2046         NaN  De-Boned Salmon, Turkey Bone Broth, Potatoes, ...
# 2047         NaN  Salmon Broth, Salmon, Chicken, Pea Protein, Ta...
# 2048       38.16  White Fish, Water Sufficient for Cooking, Baby...
# 2049         NaN  Chicken By-Product Meal, Corn, Corn Gluten Mea...
# 2050         NaN  Cooked Chicken, Hydrolyzed Soy Protein, Dehydr...
# 2051         NaN  Chicken Meal, Turkey Meal, Turkey, Chicken,  L...
# 2052         NaN  Ham, Water Sufficient For Processing, Turkey, ...
# 2053       12.99  Turkey, Chicken Meal, Whitefish Meal, Tapioca ...
# 2054         NaN  Turkey, Water Sufficient For Processing, Guar Gum
# 2055         NaN  Poultry Meal from 100% Chicken, Tapioca, Fish ...
# 2056         NaN  Boneless Turkey, Deboned Tuna, Water Sufficien...
# 2057         NaN  Tuna, Tuna Broth, Sardine, Sunflower oil, Modi...
# 2058         NaN  Chicken Broth, Chicken, Pea Pulse Protein, Tap...
# 2059         NaN  Tuna, Tuna Broth, Chicken, Sunflower oil, Modi...
# 2060       21.48  Tuna, Mackerel, Modified Tapioca Starch, Gum, ...
# 2061       17.88  Chicken, Chicken Broth, Sunflower Oil, Pumpkin...
# 2062         NaN  Chicken, Chicken Broth, Salmon, Pumpkin, Natur...
# 2063         NaN  Deboned Whitefish, Herring Meal,  Sweet Potato...
# 2064       24.00      Chicken, Inulin, Vitamins, Minerals, Taurine.
# 2065         NaN  Ground Yellow Corn, Chicken By-Product Meal, C...
# 2066         NaN  Tuna, Fish Broth, Mackerel, Tapioca Starch, Su...
# 2067         NaN  Chicken, Salmon, Chicken Broth, Sunflower Oil,...
# 2068         NaN  Salmon Broth, Salmon, Chicken, Chicken Liver, ...
# 2069         NaN  Turkey, Turkey Bone Broth, Turkey Liver, Trica...
# 2070         NaN  Deboned Tuna, Fish Broth, Vegetable Broth, Whi...
#
#       %_protein_min  %_fat_min  %_fiber_max  %_moisture_max  item_number  ...  \
# 0              3.50        3.0         1.50            76.5      82586.0  ...
# 1             11.00        4.0         1.50            78.0      76035.0  ...
# 2             10.00        5.0         1.50            78.0      76027.0  ...
# 3              6.00        2.5         1.00            76.5      80485.0  ...
# 4             30.00        9.0         5.00            12.0      76407.0  ...
# 5             40.00       15.0         4.00            10.0     131581.0  ...
# 6             34.00       13.0         3.00            12.0     100144.0  ...
# 7             31.00       11.0         4.00            12.0      99977.0  ...
# 8             30.00       13.5         8.30            10.0      93653.0  ...
# 9              8.50        3.5         1.00            76.5      69865.0  ...
# 10            34.00       13.0         4.00            12.0      48649.0  ...
# 11            10.50        2.5         2.00            81.0      49990.0  ...
# 12            40.00       13.5         2.50            12.0     100176.0  ...
# 13             4.00        3.0         1.50            76.5      82584.0  ...
# 14            40.00       18.0         2.50            12.0      91700.0  ...
# 15            30.00       11.0         3.00            12.0      76416.0  ...
# 16            32.00       15.0         3.00            10.0      93642.0  ...
# 17            24.00       18.0         5.70             8.0      50317.0  ...
# 18            32.00       16.0         3.50             9.0      50765.0  ...
# 19            10.00        2.0         1.50            80.0      75960.0  ...
# 20            12.00        2.0         1.50            78.0      76045.0  ...
# 21             8.50        2.0         1.75            82.5      49989.0  ...
# 22            29.00       17.0         3.00            10.0      48888.0  ...
# 23            11.00        4.0         1.50            78.0      76022.0  ...
# 24            30.00       11.0         3.00            12.0      76403.0  ...
# 25            30.00       13.0         1.60            11.0      69863.0  ...
# 26            42.00       18.0         3.00            10.0     154558.0  ...
# 27            11.00        2.0         1.50            80.0      76083.0  ...
# 28            34.00       17.0         3.00            10.0      76145.0  ...
# 29            10.00        2.0         1.50            82.0      67972.0  ...
# ...             ...        ...          ...             ...          ...  ...
# 2041          10.00        6.0         0.50            78.0      88459.0  ...
# 2042          15.00        2.0         2.00            82.0     226408.0  ...
# 2043          10.00        1.5         0.50            85.0     182855.0  ...
# 2044          10.00        5.5         1.50            78.0     149666.0  ...
# 2045          12.00        1.0         1.50            83.5     244672.0  ...
# 2046           8.00        4.5         1.00            82.0     138476.0  ...
# 2047           7.00        2.0         2.00            85.0     211637.0  ...
# 2048          13.00        0.3         1.00            83.0      93579.0  ...
# 2049          31.00       14.0         5.60             8.0      61815.0  ...
# 2050          41.48       37.4         3.01             4.7     236283.0  ...
# 2051          37.00       22.0         2.00            11.0     130985.0  ...
# 2052          12.00        1.0         1.50            83.5     244674.0  ...
# 2053          30.00       17.0         3.00            10.0     115345.0  ...
# 2054          10.00        0.7         0.20            85.5     244676.0  ...
# 2055          44.00       20.0         3.00            10.0     210802.0  ...
# 2056          10.00        5.0         0.50            78.0     106644.0  ...
# 2057          15.00        2.0         2.00            82.0     226410.0  ...
# 2058           8.00        3.0         1.50            82.0      86935.0  ...
# 2059          15.00        2.0         2.00            82.0     226412.0  ...
# 2060          11.00        1.0         1.00            85.0     194419.0  ...
# 2061          12.00        2.0         2.00            82.0     226426.0  ...
# 2062           9.50        9.0         1.00            78.0     145337.0  ...
# 2063          31.00       13.0         2.00            11.0     130975.0  ...
# 2064          13.00        1.5         0.50            76.5     194421.0  ...
# 2065          32.00        9.0         4.50            10.0     196202.0  ...
# 2066          10.00        1.5         0.50            85.0     182859.0  ...
# 2067          12.00        2.0         2.00            82.0     226422.0  ...
# 2068           9.00        3.0         1.00            82.0     262860.0  ...
# 2069          13.00        9.0         0.30            78.0     259254.0  ...
# 2070          10.00        4.0         1.00            81.0     150405.0  ...
#
#       kcal_per_lb kcal_per_oz kcal_per_cup kcal_per_item item_volume_for_kcal  \
# 0             NaN        77.0          NaN          77.0                  NaN
# 1             NaN         NaN          NaN          92.0                  NaN
# 2             NaN         NaN          NaN          97.0                  NaN
# 3             NaN        69.0          NaN          69.0                  NaN
# 4             NaN         NaN        364.0           NaN                  NaN
# 5             NaN         NaN        395.0           NaN                  NaN
# 6             NaN         NaN        398.0           NaN                  NaN
# 7             NaN         NaN        328.0           NaN                  NaN
# 8             NaN         NaN        302.0           NaN                  NaN
# 9             NaN       163.0          NaN         163.0                  NaN
# 10            NaN         NaN        430.0           NaN                  NaN
# 11            NaN       135.0          NaN         135.0                  NaN
# 12            NaN         NaN        414.0           NaN                  NaN
# 13            NaN        70.0          NaN          70.0                  NaN
# 14            NaN         NaN        462.0           NaN                  NaN
# 15            NaN         NaN        388.0           NaN                  NaN
# 16            NaN         NaN        399.0           NaN                  NaN
# 17            NaN         NaN        351.0           NaN                  NaN
# 18            NaN         NaN        422.0           NaN                  NaN
# 19            NaN         NaN          NaN          71.0                  NaN
# 20            NaN         NaN          NaN          85.0                  NaN
# 21            NaN        65.0          NaN          65.0                  NaN
# 22            NaN         NaN        524.0           NaN                  NaN
# 23            NaN         NaN          NaN          92.0                  NaN
# 24            NaN         NaN        389.0           NaN                  NaN
# 25            NaN         NaN        349.0           NaN                  NaN
# 26            NaN         NaN        390.0           NaN                  NaN
# 27            NaN         NaN          NaN          70.0                  NaN
# 28            NaN         NaN        469.0           NaN                  NaN
# 29            NaN         NaN          NaN          65.0                  NaN
# ...           ...         ...          ...           ...                  ...
# 2041          NaN         NaN          NaN         148.0                  NaN
# 2042          NaN         NaN          NaN          79.0                  NaN
# 2043          NaN         NaN          NaN           NaN                  NaN
# 2044          NaN         NaN          NaN         179.0                  NaN
# 2045          NaN        45.5          NaN          45.5                  NaN
# 2046          NaN         NaN          NaN           NaN                  NaN
# 2047          NaN       113.0          NaN         113.0                  NaN
# 2048          NaN         NaN          NaN           NaN                  NaN
# 2049          NaN         NaN        350.0           NaN                  NaN
# 2050       2284.0         NaN          NaN           NaN                  NaN
# 2051          NaN         NaN        531.0           NaN                  NaN
# 2052          NaN        46.9          NaN          46.9                  NaN
# 2053          NaN         NaN        375.0           NaN                  NaN
# 2054          NaN        43.4          NaN          43.4                  NaN
# 2055       1886.0         NaN        472.0           NaN                  NaN
# 2056          NaN         NaN          NaN         146.0                  NaN
# 2057          NaN         NaN          NaN          78.0                  NaN
# 2058          NaN         NaN          NaN          57.4                  NaN
# 2059          NaN         NaN          NaN          77.0                  NaN
# 2060          NaN         NaN          NaN          51.0                  NaN
# 2061          NaN         NaN          NaN          76.0                  NaN
# 2062          NaN         NaN          NaN           NaN                  NaN
# 2063          NaN         NaN        446.0           NaN                  NaN
# 2064          NaN         NaN          NaN          52.0                  NaN
# 2065          NaN         NaN        349.0           NaN                  NaN
# 2066          NaN         NaN          NaN           NaN                  NaN
# 2067          NaN         NaN          NaN          76.0                  NaN
# 2068          NaN       945.0          NaN         945.0                  NaN
# 2069          NaN       295.0        295.0           NaN                  NaN
# 2070          NaN         NaN          NaN           NaN                  NaN
#
#      total_mass_lb item_oz item_count          moisture_warning  \
# 0              NaN    2.90       24.0  % moisture max estimated
# 1              NaN    3.00       24.0                       NaN
# 2              NaN    3.00       24.0                       NaN
# 3              NaN    2.90       24.0  % moisture max estimated
# 4             16.0     NaN        1.0                       NaN
# 5             12.0     NaN        1.0                       NaN
# 6             13.0     NaN        1.0                       NaN
# 7             13.5     NaN        1.0                       NaN
# 8             16.0     NaN        1.0                       NaN
# 9              NaN    5.50       24.0  % moisture max estimated
# 10            16.0     NaN        1.0                       NaN
# 11             NaN    5.80       24.0                       NaN
# 12            14.0     NaN        1.0                       NaN
# 13             NaN    2.90       24.0  % moisture max estimated
# 14            16.0     NaN        1.0                       NaN
# 15            16.0     NaN        1.0                       NaN
# 16            16.0     NaN        1.0                       NaN
# 17             7.7     NaN        1.0                       NaN
# 18            15.0     NaN        1.0                       NaN
# 19             NaN    3.00       24.0                       NaN
# 20             NaN    3.00       24.0                       NaN
# 21             NaN    3.00       24.0                       NaN
# 22            15.5     NaN        1.0                       NaN
# 23             NaN    3.00       24.0                       NaN
# 24            16.0     NaN        1.0                       NaN
# 25             8.5     NaN        1.0  % moisture max estimated
# 26            14.0     NaN        1.0                       NaN
# 27             NaN    3.00       24.0                       NaN
# 28            12.0     NaN        1.0                       NaN
# 29             NaN    3.00       24.0                       NaN
# ...            ...     ...        ...                       ...
# 2041           NaN    5.50       24.0                       NaN
# 2042           NaN    2.80       12.0                       NaN
# 2043           NaN    2.47       24.0                       NaN
# 2044           NaN    5.50       24.0                       NaN
# 2045           NaN    2.47       24.0                       NaN
# 2046           NaN    6.40       24.0                       NaN
# 2047           NaN    2.80       12.0                       NaN
# 2048           NaN    2.47       24.0                       NaN
# 2049          22.0     NaN        1.0                       NaN
# 2050           NaN    3.50        1.0                       NaN
# 2051          15.0     NaN        1.0                       NaN
# 2052           NaN    2.47       24.0                       NaN
# 2053           3.0     NaN        1.0                       NaN
# 2054           NaN    2.47       24.0                       NaN
# 2055           NaN     NaN        1.0                       NaN
# 2056           NaN    5.50       24.0                       NaN
# 2057           NaN    2.80       12.0                       NaN
# 2058           NaN    3.00       24.0                       NaN
# 2059           NaN    2.80       12.0                       NaN
# 2060           NaN    3.50       12.0                       NaN
# 2061           NaN    2.80       12.0                       NaN
# 2062           NaN    5.50       24.0                       NaN
# 2063           4.4     NaN        1.0                       NaN
# 2064           NaN    3.00       12.0  % moisture max estimated
# 2065          20.0     NaN        1.0                       NaN
# 2066           NaN    2.47       24.0                       NaN
# 2067           NaN    2.80       12.0                       NaN
# 2068           NaN    3.00       24.0                       NaN
# 2069           NaN     NaN        3.0                       NaN
# 2070           NaN    5.50       24.0                       NaN
#
#                                      conversion_warning
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22    kcal/product required a conversion between mas...
# 23                                                  NaN
# 24                                                  NaN
# 25    kcal/product required a conversion between mas...
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 2041                                                NaN
# 2042                                                NaN
# 2043                                                NaN
# 2044                                                NaN
# 2045                                                NaN
# 2046  kcal/product required a conversion between mas...
# 2047                                                NaN
# 2048  kcal/product required a conversion between mas...
# 2049                                                NaN
# 2050  kcal/product required a conversion between mas...
# 2051                                                NaN
# 2052                                                NaN
# 2053                                                NaN
# 2054                                                NaN
# 2055                                                NaN
# 2056                                                NaN
# 2057                                                NaN
# 2058                                                NaN
# 2059                                                NaN
# 2060                                                NaN
# 2061                                                NaN
# 2062  kcal/product required a conversion between mas...
# 2063                                                NaN
# 2064                                                NaN
# 2065                                                NaN
# 2066                                                NaN
# 2067                                                NaN
# 2068                                                NaN
# 2069                                                NaN
# 2070  kcal/product required a conversion between mas...
#
# [2071 rows x 33 columns]
