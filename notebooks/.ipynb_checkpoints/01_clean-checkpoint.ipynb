# %%
from datetime import date
import pandas as pd
import sys
sys.path.append('../src')
import data.clean as clean
import numpy as np

# %% [markdown]
# # Read external data into a pandas df

# %%
# today = date.today()
# d = today.strftime('%d_%m_%Y')
d = '29_09_2020'

df = pd.read_csv(f'../data/external/raw_chewy_data_{d}.csv')

# %% [markdown]
# # Clean data
#
# ## Unpack attribute and guarenteed analysis (GA) dictionaries
# Attribute information and guarenteed analysis (GA) information are stored as dictionaries in their columns. This is because different products have different fields/numbers of fields in these tables. So first things first, expand those two columns.

# %%
# help(clean.dict_col_to_cols)

df = clean.dict_col_to_cols(df=df, col='ga_dict', ga=True)
df = clean.dict_col_to_cols(df=df, col='attr_dict', ga=False)

# %% [markdown]
# ## Fill guarenteed analysis columns missing critical statistics
#
# It is mandatory that cat food manufacturers report % protein min, % fat min, and % fiber max in their guarenteed analysis. So it's likely that when there isn't a value for one of these macros, but there is a value for a very similarly named macro, a typo has been made. So we need to fill empty macro values with the values most likely to be correct.

# %%
df['% protein min'] = df['% protein min'].fillna(df['% protein']).fillna(df['% protein max'])
df['% fat min'] = df['% fat min'].fillna(df['% fat']).fillna(df['% fat max'])
df['% fiber max'] = df['% fiber max'].fillna(df['% fiber']).fillna(df['% fiber min'])
df['% moisture max'] = df['% moisture max'].fillna(df['% moisture']).fillna(df['% moisture min'])

# df = df.dropna(thresh = df.shape[0] * 0.5, how = 'all', axis = 1)

# %% [markdown]
# ## Add up percentages of misc. guarenteed analysis componenets
# ## BROKEN - VALUES WAY TOO HIGH, MUST BE FROM MANY MAX VALUES
# There are so many miscellaneous compounds that are included in only a handful of the products' guarenteed analysis. We want the percent values for these compounds, because they will help us calculate % carbohydrates later, but we don't need them individually. So we want to add up the columns that start with '%' and are not protein, fat, fiber, moisture, or carbohydrate (a few products have this value, but we will be calculating it for all products). If the sum of these columns is 100% or greater, we know something has gone terribly wrong (I found a typo...) so we will set that value to nan.

# %%
macros = ('protein', 'fat', 'fiber', 'moisture', 'carbohydrate')

misc_components = [col for col in df if '%' in col and not any(macro in col for macro in macros)]

df['% misc components'] = df[misc_components].sum(axis=1)

df.loc[df['% misc components'] >= 100, '% misc components'] = np.nan

# %% [markdown]
# ## Extract kilocalories/mass or kilocalories/volume
# The calories column contains information about the number of kilocalories per unit mass or volume of food. However, the units are not consistent, and often multiple values are reported. So we can pull out the kcal/unit mass for dry food, and the kcal/unit volume for wet food (this is because total product size is given in mass for dry food and volume for wet food, and we'd like to eventually calculate U.S. dollar per kcal).

# %%
# help(clean.get_unit_val_col)

# kcal/unit of mass:
df = clean.get_unit_val_col(df, column_name = 'calories',
                  col_split_regex = '(?<!/) (?=\d)|,|;|:',
                  unit_name = 'kcal_per_kg',
                  unit_regex = 'kcal.*kg')

df = clean.get_unit_val_col(df, column_name = 'calories',
                  col_split_regex = '(?<!/) (?=\d)|,|;|:',
                  unit_name = 'kcal_per_lb',
                  unit_regex = 'kcal.*lb')

# kcal/unit of volume:
df = clean.get_unit_val_col(df, column_name = 'calories',
                  col_split_regex = '(?<!/) (?=\d)|,|;|:',
                  unit_name = 'kcal_per_oz',
                  unit_regex = 'kcal.*oz|kcal.*ounce')

df = clean.get_unit_val_col(df, column_name = 'calories',
                  col_split_regex = '(?<!/) (?=\d)|,|;|:',
                  unit_name = 'kcal_per_cup',
                  unit_regex = 'kcal.*cup')

# kcal/item (kcal in a single can, pouch, etc.)
df = clean.get_unit_val_col(df, column_name = 'calories',
                  col_split_regex = '(?<!/) (?=\d)|,|;|:',
                  unit_name = 'kcal_per_item',
                  unit_regex = 'kcal.*can|kcal.*pouch|kcl.*pouch|kcal.*unit|kcal.*bowl|kcal.*tray|kcal.*container|kcal.*serving|kcal.*tub|kcal.*pack',
                  clear_inconsistent_rows = False,
                  get_denom_col = True,
                  denom_name = 'item_volume_for_kcal',
                  denom_regex = '((?<=\/).*?\d+\.?\d+)')

# %% [markdown]
# ## Extract item mass, volume, and/or count
# For dry food we need the total mass of the bag, for wet food we need the total volume of the can/item unit and the number of cans/item units.

# %%
# number of lbs per item
df = clean.get_unit_val_col(df, column_name = 'name',
                  col_split_regex = ',',
                  unit_name = 'total_mass_lb',
                  unit_regex = 'lb|pound|Pound')

# if no number lbs found, get that value from the weight attribute 
# DO NOT DO THIS WEIGHTS ARE NOT ALL IN LBS
# df['total_mass_lb'] = df['total_mass_lb'].fillna(df['weight'])

# number of ounces per item
df = clean.get_unit_val_col(df, column_name = 'name',
                  col_split_regex = ',',
                  unit_name = 'item_oz',
                  unit_regex = 'oz|ounce')

# number of items
df = clean.get_unit_val_col(df, column_name = 'name',
                  col_split_regex = ',',
                  unit_name = 'item_count',
                  unit_regex = 'case of')

# if no number of items specified, set item_count to 1
df['item_count'] = df['item_count'].fillna(1)

# %% [markdown]
# # Filling values and adding warnings
# ## Nutritional info
# For nutritional information, we need to know AT LEAST the % protein min, % fat min, and % moisture. % fiber max should also be provided. To calculate the cost per kilocalorie, we need the prouct price, and the kilocalories per product.

# %%
missing_ga = df[df['% protein min'].isna() | df['% fat min'].isna() | df['% fiber max'].isna()]

print(f'There are %d products out of %d which are missing protein, fat, or fiber info.' 
      % (len(missing_ga), len(df)))

missing_moisture = df[df['% protein min'].notnull() & df['% fat min'].notnull() & df['% fiber max'].notnull() & df['% moisture max'].isna()]

print(f'There are %d products out of %d which are have all protein, fat, and fiber info, but not moisture.' 
      % (len(missing_moisture), len(df)))
# Out:
# There are 15 products out of 2107 which are missing protein, fat, or fiber info.
# There are 54 products out of 2107 which are have all protein, fat, and fiber info, but not moisture.

# %% [markdown]
# The average wet cat food and the average dry cat food are supposed to have 75-78% and 10-12% moisture max, respectively (https://www.petfoodinstitute.org/the-whole-bowl/z-pet-food-4-things-know-dry-pet-food/).
# We could assign those moisture values to the foods that are missing moisture information but have all the other nutrient values.
#
# Out of curiosity, do those values reflect the average moisture for wet and dry cat food in this data?

# %%
wet_mean = df[df['food form'].str.contains('wet food')]['% moisture max'].mean()

dry_mean = df[df['food form'].str.contains('dry food')]['% moisture max'].mean()

print(f'In this data, wet food has a mean percent moisture max of %d percent, \
and dry food has a mean percent moisture max of %d percent.' 
      % (wet_mean, dry_mean))
# Out:
# In this data, wet food has a mean percent moisture max of 80 percent, and dry food has a mean percent moisture max of 9 percent.

# %% [markdown]
# ### Assuming moisture content
# For all products that have values for protein, fat, and fiber, but are missing a value for moisture, we can fill in the moisture value with an estimate based on if the food is wet or dry. But if we do this, we should add a warning column stating that this value was estimated.

# %%
df['moisture_warning'] = np.nan

df.loc[df['food form'].str.contains('wet food') 
       & df['% protein min'].notnull() 
       & df['% fat min'].notnull() 
       & df['% fiber max'].notnull() 
       & df['% moisture max'].isna(), 
# 1527  https://www.chewy.com/snappy-tom-ultimates-tun...      24.00
# 1556  https://www.chewy.com/snappy-tom-ultimates-tun...      24.00
# 1727  https://www.chewy.com/solid-gold-touch-heaven-...      20.89
# 1883  https://www.chewy.com/hills-prescription-diet-...      45.99
# 1973  https://www.chewy.com/hills-prescription-diet-...      47.99
# 1976  https://www.chewy.com/hills-prescription-diet-...      60.99
# 2043  https://www.chewy.com/hills-prescription-diet-...      49.99
# 2058  https://www.chewy.com/hills-prescription-diet-...      68.99
# 2067  https://www.chewy.com/hills-prescription-diet-...      56.99
# 2082  https://www.chewy.com/hills-science-diet-adult...      44.99
# 2090  https://www.chewy.com/hills-prescription-diet-...      45.99
# 2096  https://www.chewy.com/hills-prescription-diet-...      42.99
# 2099  https://www.chewy.com/hills-prescription-diet-...      76.99
#
#       list_price                                 calories  \
# 7            NaN                      163 kcal/5.5 oz can
# 9            NaN                       67 kcal/2.9 oz can
# 12           NaN                       69 kcal/2.9 oz can
# 20           NaN                      169 kcal/5.5 oz can
# 22           NaN                       69 kcal/2.9 oz can
# 30           NaN                       77 kcal/2.9 oz can
# 34           NaN                             382 kcal/cup
# 47           NaN                             541 kcal/cup
# 58           NaN                      161 kcal/5.5 oz can
# 64           NaN                             351 kcal/cup
# 80           NaN                       71 kcal/2.9 oz can
# 99           NaN                     170 kcal/ 5.5 oz can
# 105          NaN                             297 kcal/cup
# 147          NaN                      188 kcal/5.5 oz can
# 165          NaN                      180 kcal/5.5 oz can
# 166          NaN                             289 kcal/cup
# 168          NaN                             268 kcal/cup
# 171          NaN                             280 kcal/cup
# 192        35.49                       71 kcal/2.8 oz can
# 258          NaN                      136 kcal/5.5-oz can
# 282          NaN                             523 kcal/cup
# 310          NaN                             468 kcal/cup
# 317        37.99                      160 kcal/5.5-oz can
# 318          NaN                       60 kcal/2.9 oz can
# 327          NaN                             472 kcal/cup
# 328        37.99                      170 kcal/5.5-oz can
# 376          NaN                       68 kcal/2.9 oz can
# 416        37.99  147 kcal/5.5 oz can, 77 kcal/2.9 oz can
# 418          NaN                             484 kcal/cup
# 420        37.99                      153 kcal/5.5-oz can
# 534          NaN                      114 kcal/5.5 oz can
# 539          NaN                      215 kcal/5.5 oz can
# 577        35.49                       78 kcal/2.8 oz can
# 624          NaN                       65 kcal/2.9 oz can
# 1233       17.55                             3710 kcal/kg
# 1361         NaN                             50 kcal/tray
# 1380         NaN                             3512 kcal/kg
# 1389         NaN                             30 kcal/tray
# 1489         NaN                                3705 kcal
# 1506         NaN                             52 kcal/tray
# 1507         NaN                             52 kcal/tray
# 1527         NaN                             44 kcal/tray
# 1556         NaN                             39 kcal/tray
# 1727       21.99              3540 kcal/kg, 430 kcals/cup
# 1883         NaN                             265 kcal/cup
# 1973         NaN               3286 kcal/kg, 289 kcal/cup
# 1976         NaN                             517 kcal/cup
# 2043         NaN                      127 kcal/5.5 oz can
# 2058         NaN                      169 kcal/5.5 oz can
# 1727  Chicken, Chicken Meal, Turkey Meal, Sweet Pota...
# 1883  Brewers Rice, Chicken By-Product Meal, Corn Gl...
# 1973  Brewers Rice, Corn Gluten Meal, Powdered Cellu...
# 1976  Corn Gluten Meal, Pork Fat, Whole Grain Corn, ...
# 2043  Water, Pork Liver, Pork By-Products, Powdered ...
# 2058  Hydrolyzed Chicken Liver, Water, Corn Starch, ...
# 2067  Water, Pork Liver, Chicken, Egg Product, Brewe...
# 2082  Chicken, Whole Grain Wheat, Corn Gluten Meal, ...
# 2090  Chicken, Cracked Pearled Barley, Corn Gluten M...
# 2096  Water, Chicken, Pork Liver, Carrots, Rice, Ric...
# 2099  Chicken, Whole Grain Corn, Corn Gluten Meal, W...
#
#                                               attr_dict  \
# 7     {'Item Number': '69865', 'Weight': '8.25\xa0po...
# 9     {'Item Number': '80489', 'Weight': '4.35\xa0po...
# 12    {'Item Number': '80487', 'Weight': '4.35\xa0po...
# 20    {'Item Number': '69857', 'Weight': '8.25\xa0po...
# 22    {'Item Number': '80485', 'Weight': '4.35\xa0po...
# 30    {'Item Number': '82586', 'Weight': '4.35\xa0po...
# 34    {'Item Number': '80480', 'Weight': '8.5\xa0pou...
# 47    {'Item Number': '69843', 'Weight': '8.5\xa0pou...
# 58    {'Item Number': '69849', 'Weight': '8.25\xa0po...
# 64    {'Item Number': '156395', 'Weight': '8.5\xa0po...
# 80    {'Item Number': '81168', 'Weight': '4.35\xa0po...
# 99    {'Item Number': '82055', 'Weight': '8.25\xa0po...
# 105   {'Item Number': '69812', 'Weight': '8.5\xa0pou...
# 147   {'Item Number': '69820', 'Weight': '8.25\xa0po...
# 165   {'Item Number': '69741', 'Weight': '8.25\xa0po...
# 166   {'Item Number': '89565', 'Weight': '12.0\xa0po...
# 168   {'Item Number': '69828', 'Weight': '8.5\xa0pou...
# 171   {'Item Number': '69826', 'Weight': '17.6\xa0po...
# 192   {'Item Number': '94018', 'Packaging Type': 'Ca...
# 258   {'Item Number': '69814', 'Weight': '8.25\xa0po...
# 282   {'Item Number': '69830', 'Weight': '4.0\xa0pou...
# 310   {'Item Number': '69855', 'Weight': '8.5\xa0pou...
# 317   {'Item Number': '52761', 'Packaging Type': 'Ca...
# 318   {'Item Number': '89570', 'Weight': '4.35\xa0po...
# 327   {'Item Number': '69853', 'Weight': '8.5\xa0pou...
# 328   {'Item Number': '48980', 'Packaging Type': 'Ca...
# 376   {'Item Number': '122117', 'Weight': '4.35\xa0p...
# 416   {'Item Number': '48963', 'Packaging Type': 'Ca...
# 418   {'Item Number': '122119', 'Weight': '6.4\xa0po...
# 420   {'Item Number': '52765', 'Packaging Type': 'Ca...
# 534   {'Item Number': '69833', 'Weight': '8.25\xa0po...
# 539   {'Item Number': '69829', 'Weight': '8.25\xa0po...
# 577   {'Item Number': '94020', 'Packaging Type': 'Ca...
# 624   {'Item Number': '85596', 'Weight': '4.35\xa0po...
# 1233  {'Item Number': '60092', 'Weight': '4.0\xa0pou...
# 1361  {'Item Number': '194431', 'Weight': '2.8\xa0po...
# 1380  {'Item Number': '236530', 'Weight': '4.0\xa0po...
# 1389  {'Item Number': '194425', 'Weight': '2.8\xa0po...
# 1489  {'Item Number': '190258', 'Weight': '4.0\xa0po...
# 1506  {'Item Number': '194423', 'Weight': '2.8\xa0po...
# 1507  {'Item Number': '194421', 'Weight': '2.8\xa0po...
# 1527  {'Item Number': '194429', 'Weight': '2.8\xa0po...
# 1556  {'Item Number': '194427', 'Weight': '2.8\xa0po...
# 1727  {'Item Number': '134150', 'Weight': '6.0\xa0po...
# 1883  {'Item Number': '69835', 'Weight': '8.5\xa0pou...
# 1973  {'Item Number': '106409', 'Weight': '6.35\xa0p...
# 1976  {'Item Number': '69819', 'Weight': '8.5\xa0pou...
# 2043  {'Item Number': '69821', 'Weight': '8.25\xa0po...
# 2058  {'Item Number': '69815', 'Weight': '8.25\xa0po...
# 2067  {'Item Number': '69844', 'Weight': '8.25\xa0po...
# 2082  {'Item Number': '90559', 'Weight': '15.5\xa0po...
# 2090  {'Item Number': '69848', 'Weight': '8.5\xa0pou...
# 2096  {'Item Number': '82584', 'Weight': '4.35\xa0po...
# 2099  {'Item Number': '69864', 'Weight': '17.6\xa0po...
#
#                                                 ga_dict  % protein min  \
# 7     {'Crude Protein': '8.5% min', 'Crude Fat': '3....            8.5
# 9     {'Crude Protein': '6.5% min', 'Crude Fat': '3....            6.5
# 12    {'Crude Protein': '6.0% min', 'Crude Fat': '2....            6.0
# 20    {'Crude Protein': '8.5% min', 'Crude Fat': '3....            8.5
# 22    {'Crude Protein': '6.0% min', 'Crude Fat': '2....            6.0
# 30    {'Crude Protein': '3.5% min', 'Crude Fat': '3....            3.5
# 34    {'Crude Protein': '30.0% min', 'Crude Fat': '1...           30.0
# 47    {'Crude Protein': '26.0% min', 'Crude Fat': '2...           26.0
# 58    {'Crude Protein': '7.5% min', 'Crude Fat': '4....            7.5
# 64    {'Crude Protein': '30.0% min', 'Crude Fat': '1...           30.0
# 80    {'Crude Protein': '5.0% min', 'Crude Fat': '3....            5.0
# 99    {'Crude Protein': '5.0% min', 'Crude Fat': '3....            5.0
# 105   {'Crude Protein': '33.0% min', 'Crude Fat': '1...           33.0
# 147   {'Crude Protein': '8.0% min', 'Crude Fat': '6....            8.0
# 165   {'Crude Protein': '8.5% min', 'Crude Fat': '5....            8.5
# 166   {'Crude Protein': '34.0% min', 'Crude Fat': '1...           34.0
# 168   {'Crude Protein': '30.0% min', 'Crude Fat': '1...           30.0
# 171   {'Crude Protein': '34.0% min', 'Crude Fat': '1...           34.0
# 192   {'Crude Protein': '6.5% min', 'Crude Fat': '2....            6.5
# 258   {'Crude Protein': '8.0% min', 'Crude Fat': '2....            8.0
# 282   {'Crude Protein': '30.0% min', 'Crude Fat': '2...           30.0
# 310   {'Crude Protein': '27.0% min', 'Crude Fat': '1...           27.0
# 317   {'Crude Protein': '7.8% min', 'Crude Fat': '2....            7.8
# 318   {'Crude Protein': '5.5% min', 'Crude Fat': '1....            5.5
# 327   {'Crude Protein': '27.0% min', 'Crude Fat': '1...           27.0
# 328   {'Crude Protein': '7.5% min', 'Crude Fat': '4....            7.5
# 376   {'Protein': '29.6% min', 'Fat': '24.9% min', '...           29.6
# 416   {'Protein': '36.7%', 'Fat': '15.0%', 'Crude Fi...           36.7
# 418   {'Crude Protein': '25.0% min', 'Crude Fat': '1...           25.0
# 420   {'Crude Protein': '7.8% min', 'Crude Fat': '2....            7.8
# 534   {'Crude Protein': '7.0% min', 'Crude Fat': '1....            7.0
# 539   {'Crude Protein': '8.5% min', 'Crude Fat': '7....            8.5
# 577   {'Crude Protein': '5.0% min', 'Crude Fat': '3....            5.0
# 624   {'Crude Protein': '7.0% min', 'Crude Fat': '2....            7.0
# 1233  {'Crude Protein': '30.0% min', 'Crude Fat': '1...           30.0
# 1361  {'Crude Protein': '12.0% min', 'Crude Fat': '1...           12.0
# 1380  {'Crude Protein': '30.0% min', 'Crude Fat': '1...           30.0
# 1389  {'Crude Protein': '8%', 'Crude Fat': '0.5%', '...            8.0
# 1489  {'Crude Protein': '34% min', 'Crude Fat': '16%...           34.0
# 1506  {'Crude Protein': '13%', 'Crude Fat': '1.5%', ...           13.0
# 1507  {'Crude Protein': '13%', 'Crude Fat': '1.5%', ...           13.0
# 1527  {'Crude Protein': '10%', 'Crude Fat': '1.5%', ...           10.0
# 1556  {'Crude Protein': '11%', 'Crude Fat': '0.5%', ...           11.0
# 1727  {'Crude Protein': '36.0% min', 'Crude Fat': '1...           36.0
# 1883  {'Crude Protein': '31.0% min', 'Crude Fat': '1...           31.0
# 1973  {'Protein': '38.2%', 'Fat': '12.9%', 'Crude Fi...           38.2
# 1976  {'Crude Protein': '30.0% min', 'Crude Fat': '2...           30.0
# 2043  {'Crude Protein': '8.0% min', 'Crude Fat': '2....            8.0
# 2058  {'Crude Protein': '7.5% min', 'Crude Fat': '2....            7.5
# 2067  {'Crude Protein': '6.0% min', 'Crude Fat': '4%...            6.0
# 2082  {'Crude Protein': '29.5% min', 'Crude Fat': '1...           29.5
# 2090  {'Crude Protein': '35.0% min', 'Crude Fat': '1...           35.0
# 2096  {'Crude Protein': '4.0% min', 'Crude Fat': '3....            4.0
# 2099  {'Crude Protein': '30.0% min', 'Crude Fat': '1...           30.0
#
#       % fat min  ...  kcal_per_kg  kcal_per_lb  kcal_per_oz  kcal_per_cup  \
# 7           3.5  ...          NaN          NaN        163.0           NaN
# 9           3.0  ...          NaN          NaN         67.0           NaN
# 12          2.5  ...          NaN          NaN         69.0           NaN
# 20          3.0  ...          NaN          NaN        169.0           NaN
# 22          2.5  ...          NaN          NaN         69.0           NaN
# 30          3.0  ...          NaN          NaN         77.0           NaN
# 34         13.0  ...          NaN          NaN          NaN         382.0
# 47         20.0  ...          NaN          NaN          NaN         541.0
# 58          4.0  ...          NaN          NaN        161.0           NaN
# 64         13.0  ...          NaN          NaN          NaN         351.0
# 80          3.0  ...          NaN          NaN         71.0           NaN
# 99          3.0  ...          NaN          NaN        170.0           NaN
# 105        10.0  ...          NaN          NaN          NaN         297.0
# 147         6.0  ...          NaN          NaN        188.0           NaN
# 165         5.2  ...          NaN          NaN        180.0           NaN
# 166        10.0  ...          NaN          NaN          NaN         289.0
# 168        14.0  ...          NaN          NaN          NaN         268.0
# 171        10.0  ...          NaN          NaN          NaN         280.0
# 192         2.0  ...          NaN          NaN         71.0           NaN
# 258         2.5  ...          NaN          NaN        136.0           NaN
# 282        23.0  ...          NaN          NaN          NaN         523.0
# 310        17.0  ...          NaN          NaN          NaN         468.0
# 317         2.5  ...          NaN          NaN        160.0           NaN
# 318         1.8  ...          NaN          NaN         60.0           NaN
# 327        17.0  ...          NaN          NaN          NaN         472.0
# 328         4.0  ...          NaN          NaN        170.0           NaN
# 376        24.9  ...          NaN          NaN         68.0           NaN
# 416        15.0  ...          NaN          NaN          NaN           NaN
# 418        19.0  ...          NaN          NaN          NaN         484.0
# 420         2.5  ...          NaN          NaN        153.0           NaN
# 534         1.0  ...          NaN          NaN        114.0           NaN
# 539         7.5  ...          NaN          NaN        215.0           NaN
# 577         3.0  ...          NaN          NaN         78.0           NaN
# 624         2.0  ...          NaN          NaN         65.0           NaN
# 1233       15.0  ...       3710.0          NaN          NaN           NaN
# 1361        1.5  ...          NaN          NaN          NaN           NaN
# 1380       14.0  ...       3512.0          NaN          NaN           NaN
# 1389        0.5  ...          NaN          NaN          NaN           NaN
# 1489       16.0  ...          NaN          NaN          NaN           NaN
# 1506        1.5  ...          NaN          NaN          NaN           NaN
# 1507        1.5  ...          NaN          NaN          NaN           NaN
# 1527        1.5  ...          NaN          NaN          NaN           NaN
# 1556        0.5  ...          NaN          NaN          NaN           NaN
# 1727       18.0  ...       3540.0          NaN          NaN         430.0
# 1883       10.0  ...          NaN          NaN          NaN         265.0
# 1973       12.9  ...       3286.0          NaN          NaN         289.0
# 1976       20.0  ...          NaN          NaN          NaN         517.0
# 2043        2.8  ...          NaN          NaN        127.0           NaN
# 2058        2.3  ...          NaN          NaN        169.0           NaN
# 2067        4.0  ...          NaN          NaN        177.0           NaN
# 2082       16.0  ...          NaN          NaN          NaN         327.0
# 2090       17.0  ...          NaN          NaN          NaN         498.0
# 2096        3.0  ...          NaN          NaN         70.0           NaN
# 2099       13.0  ...          NaN          NaN          NaN         349.0
#
#       kcal_per_item  item_volume_for_kcal  total_mass_lb  item_oz  item_count  \
# 7             163.0                   NaN            NaN      5.5        24.0
# 9              67.0                   NaN            NaN      2.9        24.0
# 12             69.0                   NaN            NaN      2.9        24.0
# 20            169.0                   NaN            NaN      5.5        24.0
# 22             69.0                   NaN            NaN      2.9        24.0
# 30             77.0                   NaN            NaN      2.9        24.0
# 34              NaN                   NaN           8.50      NaN         1.0
# 47              NaN                   NaN           8.50      NaN         1.0
# 58            161.0                   NaN            NaN      5.5        24.0
# 64              NaN                   NaN           8.50      NaN         1.0
# 80             71.0                   NaN            NaN      2.9        24.0
# 99            170.0                   NaN            NaN      5.5        24.0
# 105             NaN                   NaN           8.50      NaN         1.0
# 147           188.0                   NaN            NaN      5.5        24.0
# 165           180.0                   NaN            NaN      5.5        24.0
# 166             NaN                   NaN          12.00      NaN         1.0
# 168             NaN                   NaN           8.50      NaN         1.0
# 171             NaN                   NaN          17.60      NaN         1.0
# 192            71.0                   NaN            NaN      2.8        24.0
# 258           136.0                   NaN            NaN      5.5        24.0
# 282             NaN                   NaN           4.00      NaN         1.0
# 310             NaN                   NaN           8.50      NaN         1.0
# 317           160.0                   NaN            NaN      5.5        24.0
# 318            60.0                   NaN            NaN      2.9        24.0
# 327             NaN                   NaN           8.50      NaN         1.0
# 328           170.0                   NaN            NaN      5.5        24.0
# 376            68.0                   NaN            NaN      2.9        24.0
# 416           147.0                   NaN            NaN      5.5        24.0
# 418             NaN                   NaN           6.40      NaN         1.0
# 420           153.0                   NaN            NaN      5.5        24.0
# 534           114.0                   NaN            NaN      5.5        24.0
# 539           215.0                   NaN            NaN      5.5        24.0
# 577            78.0                   NaN            NaN      2.8        24.0
# 624            65.0                   NaN            NaN      2.9        24.0
# 1233            NaN                   NaN           4.00      NaN         1.0
# 1361           50.0                   NaN            NaN      3.0        12.0
# 1380            NaN                   NaN           4.00      NaN         1.0
# 1389           30.0                   NaN            NaN      3.0        12.0
# 1489            NaN                   NaN           4.00      NaN         1.0
# 1506           52.0                   NaN            NaN      3.0        12.0
# 1507           52.0                   NaN            NaN      3.0        12.0
# 1527           44.0                   NaN            NaN      3.0        12.0
# 1556           39.0                   NaN            NaN      3.0        12.0
# 1727            NaN                   NaN           6.00      NaN         1.0
# 1883            NaN                   NaN           8.50      NaN         1.0
# 1973            NaN                   NaN           6.35      NaN         1.0
# 1976            NaN                   NaN           8.50      NaN         1.0
# 2043          127.0                   NaN            NaN      5.5        24.0
# 2058          169.0                   NaN            NaN      5.5        24.0
# 2067          177.0                   NaN            NaN      5.5        24.0
# 2082            NaN                   NaN          15.50      NaN         1.0
# 2090            NaN                   NaN           8.50      NaN         1.0
# 2096           70.0                   NaN            NaN      2.9        24.0
# 2099            NaN                   NaN          17.60      NaN         1.0
#
#               moisture_warning
# 7     % moisture max estimated
# 9     % moisture max estimated
# 12    % moisture max estimated
# 20    % moisture max estimated
# 22    % moisture max estimated
# 30    % moisture max estimated
# 34    % moisture max estimated
# 47    % moisture max estimated
# 58    % moisture max estimated
# 64    % moisture max estimated
# 80    % moisture max estimated
# 99    % moisture max estimated
# 105   % moisture max estimated
# 147   % moisture max estimated
# 165   % moisture max estimated
# 166   % moisture max estimated
# 168   % moisture max estimated
# 171   % moisture max estimated
# 192   % moisture max estimated
# 258   % moisture max estimated
# 282   % moisture max estimated
# 310   % moisture max estimated
# 317   % moisture max estimated
# 318   % moisture max estimated
# 327   % moisture max estimated
# 328   % moisture max estimated
# 376   % moisture max estimated
# 416   % moisture max estimated
# 418   % moisture max estimated
# 420   % moisture max estimated
# 534   % moisture max estimated
# 539   % moisture max estimated
# 577   % moisture max estimated
# 624   % moisture max estimated
# 1233  % moisture max estimated
# 1361  % moisture max estimated
# 1380  % moisture max estimated
# 1389  % moisture max estimated
# 1489  % moisture max estimated
# 1506  % moisture max estimated
# 1507  % moisture max estimated
# 1527  % moisture max estimated
# 1556  % moisture max estimated
# 1727  % moisture max estimated
# 1883  % moisture max estimated
# 1973  % moisture max estimated
# 1976  % moisture max estimated
# 2043  % moisture max estimated
# 2058  % moisture max estimated
# 2067  % moisture max estimated
# 2082  % moisture max estimated
# 2090  % moisture max estimated
# 2096  % moisture max estimated
# 2099  % moisture max estimated
#
# [54 rows x 286 columns]

# %% [markdown]
# ## Kilocalories/product
# Calculating kilocalories per product is a bit trickier. We need to make sure we're not mistaking mass with volume. When wet food is measured in ounces, they are fluid ounces. But if we're given the calorie content of a wet food only in kcal/kg, we can't convert fluid ounces to kilograms, because we don't know the density of the wet food (though most wet food is ~78% water).
#
#
# So for each product we need price, and either:
#
# 1. kcal/unit of volume (cups or ounces)
# 2. item volume (cups or ounces)
#
# OR
#
# 1. kcal/unit of mass (kg or lb)
# 2. item mass (kg or lb)
#
# OR
#
# 1. kcal/item

# %%
trouble = df[((df['kcal_per_cup'].isna() & df['kcal_per_oz'].isna()) | df['item_oz'].isna()) & 
             ((df['kcal_per_kg'].isna() & df['kcal_per_lb'].isna()) | df['total_mass_lb'].isna()) &
             df['kcal_per_item'].isna()]

print(f'There are %d products out of %d which are missing required kcal/product values.' 
      % (len(trouble), len(df)))
# Out:
# There are 212 products out of 2107 which are missing required kcal/product values.

# %% [markdown]
# Let's see how many of these we could work with if we were willing to convert between mass and volume...
# We'll do calculations for kilocalories/product later, but for now we'll put a warning on these products.

# %%
annoying = trouble[(trouble['kcal_per_cup'].notnull() | trouble['kcal_per_oz'].notnull() | 
                    trouble['kcal_per_kg'].notnull() | trouble['kcal_per_lb'].notnull()) & 
                   (trouble['item_oz'].notnull() | trouble['total_mass_lb'].notnull())].copy()

print(f'We could salvage %d of the aforementioned %d products if we were willing to convert between mass and volume.' 
      % (len(annoying), len(trouble)))

df['conversion_warning'] = np.nan

df.loc[annoying.index, 'conversion_warning'] = 'kcal/product required a conversion between mass and volume'
# Out:
# We could salvage 148 of the aforementioned 212 products if we were willing to convert between mass and volume.

# %% [markdown]
# # Final clean up and save new tsv
# Get rid of columns we don't need anymore. Save as tsv because I think they look neater than csvs.

# %%
df_lite = df[['name', 'url', 'our_price', 'list_price', 'ingredients', '% protein min', '% fat min', '% fiber max', 
              '% misc components', '% moisture max', 'item number','weight', 'packaging type', 'food texture', 
              'brand', 'lifestage', 'food form', 'special diet', 'breed size', 'dimensions', 'small pet type', 
              'restricted availability', 'kcal_per_kg', 'kcal_per_lb', 'kcal_per_oz', 'kcal_per_cup', 'kcal_per_item',
              'item_volume_for_kcal', 'total_mass_lb', 'item_oz', 'item_count', 'moisture_warning', 
              'conversion_warning']]

df_lite.columns = df_lite.columns.str.replace(' ', '_')

df_lite.fillna(np.nan)

df_lite.to_csv(f'../data/interim/cleaned_chewy_data_{d}.txt', sep='\t', index=False)

# %%
ga = [col for col in df_lite if '%' in col]
df_lite.iloc[df_lite[ga].sum(axis=1).nlargest(n=20).index][ga]
# Out:
#       %_protein_min  %_fat_min  %_fiber_max  %_misc_components  %_moisture_max
# 1329           11.0       0.50          1.0           52.46058            85.0
# 1360           11.0       0.50          1.0           52.46058            85.0
# 1491           15.0       0.50          1.0           42.27048            85.0
# 1354           14.0       0.50          1.0           42.27048            85.0
# 416            36.7      15.00          7.0            7.09800            76.5
# 1377           16.0       1.00          1.0           38.89045            85.0
# 376            29.6      24.90          3.0            5.20000            76.5
# 1525           10.0       1.00          1.0           42.04051            85.0
# 1372           10.0       1.50          1.0           41.24051            85.0
# 1386           10.0       1.50          1.0           41.22047            85.0
# 1382           10.0       1.50          1.0           41.19045            85.0
# 1371           11.0       1.00          1.0           40.04051            85.0
# 1350           15.0       2.50          1.0           34.19045            85.0
# 1387           10.0       1.50          1.0           35.06045            85.0
# 1385           11.0       1.00          1.0           34.19045            85.0
# 1436            9.5       6.75         11.0            4.67000            78.0
# 1729           10.0       5.00          1.0           13.53000            78.0
# 410             9.4       5.20          3.1            9.86000            78.9
# 858            10.0       7.00          2.0            2.45000            84.0
# 1439           12.0       6.00          6.5            2.50000            78.0

# %%
df_lite.loc[1329, 'url']
# Out:
# 'https://www.chewy.com/snappy-tom-lites-chicken-salmon/dp/221043'

# %%
# Out:
# ['name',
#  'url',
#  'our_price',
#  'list_price',
#  'calories',
#  'ingredients',
#  'attr_dict',
#  'ga_dict',
#  '% protein min',
#  '% fat min',
#  '% fiber max',
#  '% moisture max',
#  '% ash max',
#  '% taurine min',
#  '% calcium min',
#  '% phosphorus min',
#  '% selenium min',
#  'vitamin a min',
#  'vitamin e min',
#  '% iron min',
#  '% omega-3 fatty acids min',
#  '% zinc min',
#  '% omega-6 fatty acids min',
#  '% linoleic acid min',
#  '% arachidonic acid min',
#  '% fat max',
#  '% potassium min',
#  '% l-carnitine min',
#  '% docosahexaenoic acid (dha) min',
#  '% calcium (ca) min',
#  '% phosphorous min',
#  '% selenium (se) min',
#  '% ash min',
#  '% calcium max',
#  '% phosphorus max',
#  '% magnesium max',
#  '% fiber min',
#  '% phosphorus (p) min',
#  '% linoleic acid (omega-6 fatty acid) min',
#  '% niacin min',
#  '% biotin min',
#  '% alpha-linolenic acid (omega-3 fatty acid) min',
#  '% linoleic acid (an omega-6 fatty acid) min',
#  '% alpha-linolenic acid (an omega-3 fatty acid) min',
#  'phosphorous min',
#  'biotin min',
#  '% ascorbic acid min',
#  '% omega 3 fatty acids* min',
#  '% omega 6 fatty acids* min',
#  'zinc min',
#  'selenium min',
#  'vitamin d min',
#  'total microorganisms min',
#  '% epa + dha min',
#  '% ascorbic acid (vitamin c) min',
#  'carnitine min',
#  '% sodium max',
#  'zinc (zn) min',
#  'selenium (se) min',
#  'bacillus coagulans min',
#  '% magnesium min',
#  '% methionine min',
#  '% omega 6 fatty acids min',
#  '% ascorbic acid (source of vitamin c) min',
#  'total microorganisms (bacillus coagulan) min',
#  '% dietary starch max',
#  '% sugars max',
#  '% taurine max',
#  '% dha min',
#  '% sodium min',
#  '% protein max',
#  '% omega-6 fatty acids* min',
#  'magnesium max',
#  '% glucosamine min',
#  '% chondroitin sulfate min',
#  '% vitamin c min',
#  '% omega 3 fatty acids min',
#  '% carbohydrate max',
#  'l-carnitine min',
#  '% docosahexaenoic acid (dha min',
#  'bacillus coagulants min',
#  '% eicosapentaenoic acid (epa) min',
#  '% docosahexaenoic acid min',
#  'vitamin c min',
#  '% total dietary fiber min',
#  '% carbohydrates max',
#  '% ascorbic acid (source of vitamin c)* min',
#  '% l-carnitine* min',
#  '% eicosapentaenoic acid min',
#  '% moisture min',
#  'vitamin e',
#  '% l-carnitine',
#  '% lineoleic acid min',
#  '% phos max',
#  '% omega-6 fatty acid min',
#  '% omega-3 fatty acid min',
#  'bacillus coagulants',
#  '% selenium',
#  'beta carotene min',
#  '% dha & epa min',
#  '% lysine min',
#  '% methionine-cystine',
#  '% pantothenic acid',
#  '% niacin',
#  '% carbohydrate / nfe min',
#  'vitamin c',
#  '% total omega-3 fatty acids min',
#  'carnitine',
#  '% i-carnitie',
#  'total lactic acid microorganisms* min',
#  '% protein',
#  '% fat',
#  '% fiber',
#  '% carbohydrate / nfe',
#  '% phosphorous',
#  '% sodium',
#  '% potassium',
#  '% magnesium',
#  '% taurine',
#  '% total omega-3 fa',
#  '% total omega-6 fa',
#  '% phosphorous max',
#  '% total omega-3 fa min',
#  '% ara min',
#  '% choline min',
#  'beta-carotene min',
#  '% soluble fiber min',
#  '% lutein min',
#  'total lactic acid microorganisms min',
#  '% zinc (zn) min',
#  '% chondroitin sulfate max',
#  '% docosahexanoic acid (dha) min',
#  '% l carnitine min',
#  '% dha (doxosahexaenoic acid) min',
#  '% dha (docosahexaenoic acid) min',
#  '% omega-3 fatty acids* min',
#  'beta-carotene* min',
#  '% carnitine',
#  'papain',
#  'bromelain',
#  '% omega-3 fatty acids*',
#  'docosahexaenoic acid',
#  '% omega 6 min',
#  '% omega 3 min',
#  'glucosamine min',
#  '% eicosapentaenoic acid (epa)',
#  '% phosphorus',
#  '% carbohydrates',
#  'total microorganisms (bacillus coagulans) min',
#  '% linoelic acid min',
#  '% potassium (k) min',
#  '% magnesium (mg) max',
#  '% pottassium min',
#  '% copper',
#  '% zinc',
#  '% biotin',
#  '% ash',
#  '% moisture',
#  '% omega-6 fatty acids',
#  '% omega-3 fatty acids',
#  'carbohydrates min',
#  '% vitamin e min',
#  'fat min',
#  'bacillus coagulans',
#  'total microorganisms* min',
#  '% ascorbic acid',
#  '% linoleic acid (omega-6) min',
#  '% alpha linolenic acid (omega-3) min',
#  'lactobacillus acidophilus min',
#  'cellulase min',
#  '% omega-6 min',
#  '% omega-3 min',
#  '% linoleic acid max',
#  '% manganese min',
#  '% vitamin e max',
#  '% chloride min',
#  '% dlmethionine min',
#  'calcium/phosphorous ratio',
#  '% glucosamine',
#  '% carbohydrates min',
#  '% glucosamine max',
#  'calcium / phosphorous ratio',
#  '% eicosapentaenoic + docosahexaenoic acid min',
#  '% potassium max',
#  'total microorganisms (lactobacillus aciphophilus, lactobacillus plantarum, lactobacillus reuteri, bifidobacterium animalis, enterococcus faecium) min',
#  '% ash content max',
#  'total microorganisms*',
#  '% omega-6 (linoleic acid) min',
#  '% omega-3 (linolenic acid) min',
#  '% dha max',
#  '% omega-3 (linolenic acid) max',
#  'omega-3 fatty acids min',
#  '% omega 6 fatty acids max',
#  '% asboric acid (vitamin c) min',
#  'omega-6 fatty acids min',
#  'fiber max',
#  '% epa min',
#  '% apa min',
#  'moisture max',
#  '% docosahexaenoic (dha) min',
#  '% asboric avid (vitamin c) min',
#  '% calicum min',
#  '% docosapentaenoic acid (dha min',
#  '% ash, max',
#  '% docosaexaenoic (dha) min',
#  '% eicosapentaenoic (epa) min',
#  '% salt',
#  '% arginine',
#  '% methionine',
#  'vitamin a',
#  'vitamin d',
#  '% thiamin b1',
#  '% niacin b3',
#  '% panthothenic acid',
#  '% choline',
#  '% folic acid',
#  '% iron',
#  '% manganese',
#  '% calcium',
#  '% iodine',
#  '% omega-6 fatty acids max',
#  '% salt min',
#  '% eicosapentaenoic acid, (epa) min',
#  '% decosahexaenoic acid, (dha) min',
#  'phosphorus',
#  '% zinc (zn)',
#  '% beta-carotene min',
#  '% calcuim',
#  '% starch',
#  '% total sugar',
#  '% inulin',
#  '% water-soluble chloride min',
#  '% calcium(ca) min',
#  '% phosphorus(p) min',
#  'taurine min',
#  'ascorbic acid',
#  'ash max',
#  '% ascorbic acid (vitamin c)* min',
#  '% potasssium min',
#  '% glucosamine hc min',
#  '% phosporus min',
#  'microorganisms (lactobacillus acidophilus, enterococcus faecium) min',
#  '% total omega-6 fatty acids min',
#  '% omega-6 fatty acids*',
#  '% docosahexaenoic acid (dha) (an omega 3 fatty acid) min',
#  '% dha',
#  'vitamin emin min',
#  'total microorganisms',
#  '% riboflavin min',
#  '% pantothenic acid min',
#  '% pyridoxine min',
#  '% vitamin b12 min',
#  '% omega3 fatty acids min',
#  'magnesium (mg) max',
#  '% chondroitin sulfate',
#  '% lycopene',
#  '% carbohydrate/nfe',
#  '% iodine max',
#  '% dha (an omega fatty acid) min',
#  '% omega 6 fatty acid min',
#  '% tryptophan min',
#  'linoleic acid min',
#  '% ara* min',
#  'item number',
#  'weight',
#  'packaging type',
#  'food texture',
#  'brand',
#  'lifestage',
#  'food form',
#  'special diet',
#  'breed size',
#  'dimensions',
#  'small pet type',
#  'restricted availability',
#  '% misc components',
#  'kcal_per_kg',
#  'kcal_per_lb',
#  'kcal_per_oz',
#  'kcal_per_cup',
#  'kcal_per_item',
#  'item_volume_for_kcal',
#  'total_mass_lb',
#  'item_oz',
#  'item_count',
#  'moisture_warning',
#  'conversion_warning']
